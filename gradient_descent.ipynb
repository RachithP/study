# %% [markdown]
# <a href="https://colab.research.google.com/github/RachithP/study/blob/main/gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Learnings from https://medium.com/correll-lab/a-primer-on-using-pytorch-optimizers-7a97e0999095

# %% [markdown]
# Perform Gradient Descent on a convex function

# %% [markdown]
# Let's plot some functions, and choose one
#
# 1. y=(x-3)^2
# 2. y = x^2
# 3. y = x^3

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# Define the x range
x = np.linspace(-10, 10, 500)

# Define the functions
y1 = (x - 3)**2
y2 = x**2
y3 = x**3

# Plot the functions
fig, axs = plt.subplots(1, 3, figsize=(10, 4))

# Plot y1
axs[0].plot(x, y1, label='y = (x-3)^2', color='blue')
axs[0].set_title('y = (x-3)^2')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].grid()
axs[0].legend()

# Plot y2
axs[1].plot(x, y2, label='y = x^2', color='green')
axs[1].set_title('y = x^2')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y')
axs[1].grid()
axs[1].legend()

# Plot y3
axs[2].plot(x, y3, label='y = x^3', color='red')
axs[2].set_title('y = x^3')
axs[2].set_xlabel('x')
axs[2].set_ylabel('y')
axs[2].grid()
axs[2].legend()

plt.tight_layout()

# Show the plot
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch

num_iterations = 10
learning_rate = 0.1
x = torch.tensor([0.0], requires_grad=True)

for step in range(num_iterations):

    y = (x-3)**2

    y.backward()

    with torch.no_grad():
        x -= learning_rate*x.grad
        x.grad.zero_()

    print(f"Step {step+1}: x = {x.item()}, y = {y.item()}")

print(f"Converged local minima is at {x=}")
# Out:
# Step 1: x = 0.6000000238418579, y = 9.0
# Step 2: x = 1.0800000429153442, y = 5.760000228881836
# Step 3: x = 1.4639999866485596, y = 3.6863999366760254
# Step 4: x = 1.7711999416351318, y = 2.3592960834503174
# Step 5: x = 2.0169599056243896, y = 1.5099495649337769
# Step 6: x = 2.2135679721832275, y = 0.9663678407669067
# Step 7: x = 2.370854377746582, y = 0.6184753179550171
# Step 8: x = 2.4966835975646973, y = 0.39582422375679016
# Step 9: x = 2.597346782684326, y = 0.2533273994922638
# Step 10: x = 2.677877426147461, y = 0.16212961077690125
# Converged local minima is at x=tensor([2.6779], requires_grad=True)

# %% [markdown]
# We can see that the local minima of x = 3 was not acheived. However, we can see that the value of x is approaching it, so there are a few ways we can go next
# 1. Increase learning rate to try and converge faster in the same #iterations
# 2. Increase #iterations

# %% [markdown]
# Ok, now let's see what happens when you try GD on a non-convex function such as x^3

# %%
num_iterations = 10
learning_rate = 0.1
# x = torch.tensor([0.0], requires_grad=True) # if you do this, the min is already acheived, so no updates will happen
x = torch.rand(size=(1,1), requires_grad=True)

for step in range(num_iterations):

    y = (x)**3

    y.backward()

    with torch.no_grad():
        x -= learning_rate*x.grad
        x.grad.zero_()

    print(f"Step {step+1}: x = {x.item()}, y = {y.item()}")

print(f"Converged local minima is at {x=}")
# Out:
# Step 1: x = 0.5189800262451172, y = 0.26587745547294617
# Step 2: x = 0.4381779432296753, y = 0.13978222012519836
# Step 3: x = 0.3805779814720154, y = 0.08413012325763702
# Step 4: x = 0.33712610602378845, y = 0.05512276291847229
# Step 5: x = 0.3030298948287964, y = 0.03831573203206062
# Step 6: x = 0.2754817605018616, y = 0.02782636135816574
# Step 7: x = 0.25271469354629517, y = 0.020906364545226097
# Step 8: x = 0.23355527222156525, y = 0.016139551997184753
# Step 9: x = 0.21719084680080414, y = 0.012739988043904305
# Step 10: x = 0.203039288520813, y = 0.010245297104120255
# Converged local minima is at x=tensor([[0.2030]], requires_grad=True)

# %% [markdown]
# It very much depends on whether x is initialized as a +ve or -ve number. If +ve, we are descending, but what happens when x is -ve?

# %%
num_iterations = 100
learning_rate = 1.0
# x = torch.tensor([0.0], requires_grad=True) # if you do this, the min is already acheived, so no updates will happen
x = torch.rand(size=(1, 1), requires_grad=True)

for step in range(num_iterations):

    y = (x)**3

    y.backward()

    with torch.no_grad():
        x -= learning_rate * x.grad
        x.grad.zero_()

    print(f"Step {step+1}: x = {x.item()}, y = {y.item()}")

print(f"Converged local minima is at {x=}")
# Out:
# Step 1: x = -1.0425119400024414, y = 0.47321921586990356
# Step 2: x = -4.303005218505859, y = -1.133034348487854
# Step 3: x = -59.85056686401367, y = -79.67381286621094
# Step 4: x = -10806.1220703125, y = -214390.140625
# Step 5: x = -350327616.0, y = -1261855440896.0
# Step 6: x = -3.681883048325939e+17, y = -4.299550967799158e+25
# Step 7: x = -4.0668786363562684e+35, y = -inf
# Step 8: x = -inf, y = -inf
# Step 9: x = -inf, y = -inf
# Step 10: x = -inf, y = -inf
# Step 11: x = -inf, y = -inf
# Step 12: x = -inf, y = -inf
# Step 13: x = -inf, y = -inf
# Step 14: x = -inf, y = -inf
# Step 15: x = -inf, y = -inf
# Step 16: x = -inf, y = -inf
# Step 17: x = -inf, y = -inf
# Step 18: x = -inf, y = -inf
# Step 19: x = -inf, y = -inf
# Step 20: x = -inf, y = -inf
# Step 21: x = -inf, y = -inf
# Step 22: x = -inf, y = -inf
# Step 23: x = -inf, y = -inf
# Step 24: x = -inf, y = -inf
# Step 25: x = -inf, y = -inf
# Step 26: x = -inf, y = -inf
# Step 27: x = -inf, y = -inf
# Step 28: x = -inf, y = -inf
# Step 29: x = -inf, y = -inf
# Step 30: x = -inf, y = -inf
# Step 31: x = -inf, y = -inf
# Step 32: x = -inf, y = -inf
# Step 33: x = -inf, y = -inf
# Step 34: x = -inf, y = -inf
# Step 35: x = -inf, y = -inf
# Step 36: x = -inf, y = -inf
# Step 37: x = -inf, y = -inf
# Step 38: x = -inf, y = -inf
# Step 39: x = -inf, y = -inf
# Step 40: x = -inf, y = -inf
# Step 41: x = -inf, y = -inf
# Step 42: x = -inf, y = -inf
# Step 43: x = -inf, y = -inf
# Step 44: x = -inf, y = -inf
# Step 45: x = -inf, y = -inf
# Step 46: x = -inf, y = -inf
# Step 47: x = -inf, y = -inf
# Step 48: x = -inf, y = -inf
# Step 49: x = -inf, y = -inf
# Step 50: x = -inf, y = -inf
# Step 51: x = -inf, y = -inf
# Step 52: x = -inf, y = -inf
# Step 53: x = -inf, y = -inf
# Step 54: x = -inf, y = -inf
# Step 55: x = -inf, y = -inf
# Step 56: x = -inf, y = -inf
# Step 57: x = -inf, y = -inf
# Step 58: x = -inf, y = -inf
# Step 59: x = -inf, y = -inf
# Step 60: x = -inf, y = -inf
# Step 61: x = -inf, y = -inf
# Step 62: x = -inf, y = -inf
# Step 63: x = -inf, y = -inf
# Step 64: x = -inf, y = -inf
# Step 65: x = -inf, y = -inf
# Step 66: x = -inf, y = -inf
# Step 67: x = -inf, y = -inf
# Step 68: x = -inf, y = -inf
# Step 69: x = -inf, y = -inf
# Step 70: x = -inf, y = -inf
# Step 71: x = -inf, y = -inf
# Step 72: x = -inf, y = -inf
# Step 73: x = -inf, y = -inf
# Step 74: x = -inf, y = -inf
# Step 75: x = -inf, y = -inf
# Step 76: x = -inf, y = -inf
# Step 77: x = -inf, y = -inf
# Step 78: x = -inf, y = -inf
# Step 79: x = -inf, y = -inf
# Step 80: x = -inf, y = -inf
# Step 81: x = -inf, y = -inf
# Step 82: x = -inf, y = -inf
# Step 83: x = -inf, y = -inf
# Step 84: x = -inf, y = -inf
# Step 85: x = -inf, y = -inf
# Step 86: x = -inf, y = -inf
# Step 87: x = -inf, y = -inf
# Step 88: x = -inf, y = -inf
# Step 89: x = -inf, y = -inf
# Step 90: x = -inf, y = -inf
# Step 91: x = -inf, y = -inf
# Step 92: x = -inf, y = -inf
# Step 93: x = -inf, y = -inf
# Step 94: x = -inf, y = -inf
# Step 95: x = -inf, y = -inf
# Step 96: x = -inf, y = -inf
# Step 97: x = -inf, y = -inf
# Step 98: x = -inf, y = -inf
# Step 99: x = -inf, y = -inf
# Step 100: x = -inf, y = -inf
# Converged local minima is at x=tensor([[-inf]], requires_grad=True)

# %% [markdown]
# As you can see, we are descending, but away from the minima at x = 0, because as x=-inf, there is a global minima

# %% [markdown]
# Now, let's use PyTorch's optimziers to do the gradient computation

# %%
from torch.optim import SGD

num_iterations = 10
x = torch.tensor([0.0], requires_grad=True)

optimizer = SGD([x], lr=0.1)

for step in range(num_iterations):

    y = (x-3)**2

    optimizer.zero_grad()

    y.backward()

    optimizer.step()

    print(f"Step {step+1}: x = {x.item()}, y = {y.item()}")

print(f"Converged local minima is at {x=}")
# Out:
# Step 1: x = 0.6000000238418579, y = 9.0
# Step 2: x = 1.0800000429153442, y = 5.760000228881836
# Step 3: x = 1.4639999866485596, y = 3.6863999366760254
# Step 4: x = 1.7711999416351318, y = 2.3592960834503174
# Step 5: x = 2.0169599056243896, y = 1.5099495649337769
# Step 6: x = 2.2135679721832275, y = 0.9663678407669067
# Step 7: x = 2.370854377746582, y = 0.6184753179550171
# Step 8: x = 2.4966835975646973, y = 0.39582422375679016
# Step 9: x = 2.597346782684326, y = 0.2533273994922638
# Step 10: x = 2.677877426147461, y = 0.16212961077690125
# Converged local minima is at x=tensor([2.6779], requires_grad=True)

# %% [markdown]
# Let's try using this optimizer on a logistic regression problem

# %%
# create a random dataset

torch.manual_seed(42)

X = torch.randn(2, 1000)
Y = (X[0,:] + X[1,:] > 0).float().unsqueeze(0)

m = X.shape[1]
nx = X.shape[0]

print(f"{X.shape=}, {Y.shape=}")
# Out:
# X.shape=torch.Size([2, 1000]), Y.shape=torch.Size([1, 1000])

# %%
def sigmoid(z):
    return 1 / (1+torch.exp(-z))

def binary_cross_entropy_loss(y_pred, y_true):
    return -torch.mean(y_true * torch.log(y_pred + 1e-8) + (1-y_true) * torch.log(1 - y_pred + 1e-8))

# %% [markdown]
# Let's do gradient descent both manually, and using `torch.optim.SGD`

# %%
num_iterations = 100
learning_rate = 0.1

# manual

w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)
for step in range(num_iterations):

    z = w.T @ X + b
    a = sigmoid(z)

    loss = binary_cross_entropy_loss(a, Y)

    loss.backward()

    with torch.no_grad():
        w -= learning_rate * w.grad
        b -= learning_rate * b.grad
        w.grad.zero_()
        b.grad.zero_()

    print(f"Epoch {step+1}: Loss = {loss.item():.4f}")
# Out:
# Epoch 1: Loss = 0.6931
# Epoch 2: Loss = 0.6777
# Epoch 3: Loss = 0.6631
# Epoch 4: Loss = 0.6491
# Epoch 5: Loss = 0.6358
# Epoch 6: Loss = 0.6231
# Epoch 7: Loss = 0.6110
# Epoch 8: Loss = 0.5994
# Epoch 9: Loss = 0.5884
# Epoch 10: Loss = 0.5779
# Epoch 11: Loss = 0.5679
# Epoch 12: Loss = 0.5583
# Epoch 13: Loss = 0.5491
# Epoch 14: Loss = 0.5403
# Epoch 15: Loss = 0.5319
# Epoch 16: Loss = 0.5238
# Epoch 17: Loss = 0.5161
# Epoch 18: Loss = 0.5087
# Epoch 19: Loss = 0.5015
# Epoch 20: Loss = 0.4947
# Epoch 21: Loss = 0.4881
# Epoch 22: Loss = 0.4817
# Epoch 23: Loss = 0.4756
# Epoch 24: Loss = 0.4697
# Epoch 25: Loss = 0.4641
# Epoch 26: Loss = 0.4586
# Epoch 27: Loss = 0.4533
# Epoch 28: Loss = 0.4482
# Epoch 29: Loss = 0.4432
# Epoch 30: Loss = 0.4385
# Epoch 31: Loss = 0.4338
# Epoch 32: Loss = 0.4294
# Epoch 33: Loss = 0.4250
# Epoch 34: Loss = 0.4208
# Epoch 35: Loss = 0.4167
# Epoch 36: Loss = 0.4128
# Epoch 37: Loss = 0.4089
# Epoch 38: Loss = 0.4052
# Epoch 39: Loss = 0.4016
# Epoch 40: Loss = 0.3980
# Epoch 41: Loss = 0.3946
# Epoch 42: Loss = 0.3913
# Epoch 43: Loss = 0.3880
# Epoch 44: Loss = 0.3849
# Epoch 45: Loss = 0.3818
# Epoch 46: Loss = 0.3788
# Epoch 47: Loss = 0.3758
# Epoch 48: Loss = 0.3730
# Epoch 49: Loss = 0.3702
# Epoch 50: Loss = 0.3675
# Epoch 51: Loss = 0.3648
# Epoch 52: Loss = 0.3622
# Epoch 53: Loss = 0.3597
# Epoch 54: Loss = 0.3572
# Epoch 55: Loss = 0.3548
# Epoch 56: Loss = 0.3524
# Epoch 57: Loss = 0.3501
# Epoch 58: Loss = 0.3478
# Epoch 59: Loss = 0.3456
# Epoch 60: Loss = 0.3434
# Epoch 61: Loss = 0.3413
# Epoch 62: Loss = 0.3392
# Epoch 63: Loss = 0.3372
# Epoch 64: Loss = 0.3352
# Epoch 65: Loss = 0.3332
# Epoch 66: Loss = 0.3313
# Epoch 67: Loss = 0.3294
# Epoch 68: Loss = 0.3276
# Epoch 69: Loss = 0.3257
# Epoch 70: Loss = 0.3240
# Epoch 71: Loss = 0.3222
# Epoch 72: Loss = 0.3205
# Epoch 73: Loss = 0.3188
# Epoch 74: Loss = 0.3172
# Epoch 75: Loss = 0.3155
# Epoch 76: Loss = 0.3139
# Epoch 77: Loss = 0.3124
# Epoch 78: Loss = 0.3108
# Epoch 79: Loss = 0.3093
# Epoch 80: Loss = 0.3078
# Epoch 81: Loss = 0.3063
# Epoch 82: Loss = 0.3049
# Epoch 83: Loss = 0.3035
# Epoch 84: Loss = 0.3021
# Epoch 85: Loss = 0.3007
# Epoch 86: Loss = 0.2993
# Epoch 87: Loss = 0.2980
# Epoch 88: Loss = 0.2967
# Epoch 89: Loss = 0.2954
# Epoch 90: Loss = 0.2941
# Epoch 91: Loss = 0.2929
# Epoch 92: Loss = 0.2916
# Epoch 93: Loss = 0.2904
# Epoch 94: Loss = 0.2892
# Epoch 95: Loss = 0.2880
# Epoch 96: Loss = 0.2869
# Epoch 97: Loss = 0.2857
# Epoch 98: Loss = 0.2846
# Epoch 99: Loss = 0.2834
# Epoch 100: Loss = 0.2823

# %%
# torch.optim.SGD
num_iterations = 100
learning_rate = 0.1

w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)

optimizer = SGD([w, b], lr=learning_rate)

for step in range(num_iterations):

    z = w.T @ X + b
    a = sigmoid(z)

    loss = binary_cross_entropy_loss(a, Y)

    optimizer.zero_grad()

    loss.backward()

    optimizer.step()

    print(f"Epoch {step+1}: Loss = {loss.item():.4f}")
# Out:
# Epoch 1: Loss = 0.6931
# Epoch 2: Loss = 0.6777
# Epoch 3: Loss = 0.6631
# Epoch 4: Loss = 0.6491
# Epoch 5: Loss = 0.6358
# Epoch 6: Loss = 0.6231
# Epoch 7: Loss = 0.6110
# Epoch 8: Loss = 0.5994
# Epoch 9: Loss = 0.5884
# Epoch 10: Loss = 0.5779
# Epoch 11: Loss = 0.5679
# Epoch 12: Loss = 0.5583
# Epoch 13: Loss = 0.5491
# Epoch 14: Loss = 0.5403
# Epoch 15: Loss = 0.5319
# Epoch 16: Loss = 0.5238
# Epoch 17: Loss = 0.5161
# Epoch 18: Loss = 0.5087
# Epoch 19: Loss = 0.5015
# Epoch 20: Loss = 0.4947
# Epoch 21: Loss = 0.4881
# Epoch 22: Loss = 0.4817
# Epoch 23: Loss = 0.4756
# Epoch 24: Loss = 0.4697
# Epoch 25: Loss = 0.4641
# Epoch 26: Loss = 0.4586
# Epoch 27: Loss = 0.4533
# Epoch 28: Loss = 0.4482
# Epoch 29: Loss = 0.4432
# Epoch 30: Loss = 0.4385
# Epoch 31: Loss = 0.4338
# Epoch 32: Loss = 0.4294
# Epoch 33: Loss = 0.4250
# Epoch 34: Loss = 0.4208
# Epoch 35: Loss = 0.4167
# Epoch 36: Loss = 0.4128
# Epoch 37: Loss = 0.4089
# Epoch 38: Loss = 0.4052
# Epoch 39: Loss = 0.4016
# Epoch 40: Loss = 0.3980
# Epoch 41: Loss = 0.3946
# Epoch 42: Loss = 0.3913
# Epoch 43: Loss = 0.3880
# Epoch 44: Loss = 0.3849
# Epoch 45: Loss = 0.3818
# Epoch 46: Loss = 0.3788
# Epoch 47: Loss = 0.3758
# Epoch 48: Loss = 0.3730
# Epoch 49: Loss = 0.3702
# Epoch 50: Loss = 0.3675
# Epoch 51: Loss = 0.3648
# Epoch 52: Loss = 0.3622
# Epoch 53: Loss = 0.3597
# Epoch 54: Loss = 0.3572
# Epoch 55: Loss = 0.3548
# Epoch 56: Loss = 0.3524
# Epoch 57: Loss = 0.3501
# Epoch 58: Loss = 0.3478
# Epoch 59: Loss = 0.3456
# Epoch 60: Loss = 0.3434
# Epoch 61: Loss = 0.3413
# Epoch 62: Loss = 0.3392
# Epoch 63: Loss = 0.3372
# Epoch 64: Loss = 0.3352
# Epoch 65: Loss = 0.3332
# Epoch 66: Loss = 0.3313
# Epoch 67: Loss = 0.3294
# Epoch 68: Loss = 0.3276
# Epoch 69: Loss = 0.3257
# Epoch 70: Loss = 0.3240
# Epoch 71: Loss = 0.3222
# Epoch 72: Loss = 0.3205
# Epoch 73: Loss = 0.3188
# Epoch 74: Loss = 0.3172
# Epoch 75: Loss = 0.3155
# Epoch 76: Loss = 0.3139
# Epoch 77: Loss = 0.3124
# Epoch 78: Loss = 0.3108
# Epoch 79: Loss = 0.3093
# Epoch 80: Loss = 0.3078
# Epoch 81: Loss = 0.3063
# Epoch 82: Loss = 0.3049
# Epoch 83: Loss = 0.3035
# Epoch 84: Loss = 0.3021
# Epoch 85: Loss = 0.3007
# Epoch 86: Loss = 0.2993
# Epoch 87: Loss = 0.2980
# Epoch 88: Loss = 0.2967
# Epoch 89: Loss = 0.2954
# Epoch 90: Loss = 0.2941
# Epoch 91: Loss = 0.2929
# Epoch 92: Loss = 0.2916
# Epoch 93: Loss = 0.2904
# Epoch 94: Loss = 0.2892
# Epoch 95: Loss = 0.2880
# Epoch 96: Loss = 0.2869
# Epoch 97: Loss = 0.2857
# Epoch 98: Loss = 0.2846
# Epoch 99: Loss = 0.2834
# Epoch 100: Loss = 0.2823

# %%
# torch.optim.SGD
num_iterations = 100
learning_rate = 0.1

w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)

optimizer = SGD([w, b], lr=learning_rate)

for step in range(num_iterations):

    # shuffle X, Y
    perm = torch.randperm(m)
    X_shuffled, Y_shuffled = X[:, perm], Y[:, perm]

    epoch_loss = 0.0

    # use mini-batches
    for batch in range(0, m, 100):

        X_batch, Y_batch = X_shuffled[:, batch:batch+100], Y_shuffled[:, batch:batch+100]

        z = w.T @ X_shuffled + b
        a = sigmoid(z)

        loss = binary_cross_entropy_loss(a, Y_shuffled)
        epoch_loss += loss

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        print(f"Batch {batch}: Loss = {loss.item():.4f}")

    print(f"Epoch {step+1}: Loss = {epoch_loss.item():.4f}")
# Out:
# Batch 0: Loss = 0.6931
# Batch 100: Loss = 0.6777
# Batch 200: Loss = 0.6631
# Batch 300: Loss = 0.6491
# Batch 400: Loss = 0.6358
# Batch 500: Loss = 0.6231
# Batch 600: Loss = 0.6110
# Batch 700: Loss = 0.5994
# Batch 800: Loss = 0.5884
# Batch 900: Loss = 0.5779
# Epoch 1: Loss = 6.3186
# Batch 0: Loss = 0.5679
# Batch 100: Loss = 0.5583
# Batch 200: Loss = 0.5491
# Batch 300: Loss = 0.5403
# Batch 400: Loss = 0.5319
# Batch 500: Loss = 0.5238
# Batch 600: Loss = 0.5161
# Batch 700: Loss = 0.5087
# Batch 800: Loss = 0.5015
# Batch 900: Loss = 0.4947
# Epoch 2: Loss = 5.2923
# Batch 0: Loss = 0.4881
# Batch 100: Loss = 0.4817
# Batch 200: Loss = 0.4756
# Batch 300: Loss = 0.4697
# Batch 400: Loss = 0.4641
# Batch 500: Loss = 0.4586
# Batch 600: Loss = 0.4533
# Batch 700: Loss = 0.4482
# Batch 800: Loss = 0.4432
# Batch 900: Loss = 0.4385
# Epoch 3: Loss = 4.6211
# Batch 0: Loss = 0.4338
# Batch 100: Loss = 0.4294
# Batch 200: Loss = 0.4250
# Batch 300: Loss = 0.4208
# Batch 400: Loss = 0.4167
# Batch 500: Loss = 0.4128
# Batch 600: Loss = 0.4089
# Batch 700: Loss = 0.4052
# Batch 800: Loss = 0.4016
# Batch 900: Loss = 0.3980
# Epoch 4: Loss = 4.1522
# Batch 0: Loss = 0.3946
# Batch 100: Loss = 0.3913
# Batch 200: Loss = 0.3880
# Batch 300: Loss = 0.3849
# Batch 400: Loss = 0.3818
# Batch 500: Loss = 0.3788
# Batch 600: Loss = 0.3758
# Batch 700: Loss = 0.3730
# Batch 800: Loss = 0.3702
# Batch 900: Loss = 0.3675
# Epoch 5: Loss = 3.8057
# Batch 0: Loss = 0.3648
# Batch 100: Loss = 0.3622
# Batch 200: Loss = 0.3597
# Batch 300: Loss = 0.3572
# Batch 400: Loss = 0.3548
# Batch 500: Loss = 0.3524
# Batch 600: Loss = 0.3501
# Batch 700: Loss = 0.3478
# Batch 800: Loss = 0.3456
# Batch 900: Loss = 0.3434
# Epoch 6: Loss = 3.5381
# Batch 0: Loss = 0.3413
# Batch 100: Loss = 0.3392
# Batch 200: Loss = 0.3372
# Batch 300: Loss = 0.3352
# Batch 400: Loss = 0.3332
# Batch 500: Loss = 0.3313
# Batch 600: Loss = 0.3294
# Batch 700: Loss = 0.3276
# Batch 800: Loss = 0.3257
# Batch 900: Loss = 0.3240
# Epoch 7: Loss = 3.3241
# Batch 0: Loss = 0.3222
# Batch 100: Loss = 0.3205
# Batch 200: Loss = 0.3188
# Batch 300: Loss = 0.3172
# Batch 400: Loss = 0.3155
# Batch 500: Loss = 0.3139
# Batch 600: Loss = 0.3124
# Batch 700: Loss = 0.3108
# Batch 800: Loss = 0.3093
# Batch 900: Loss = 0.3078
# Epoch 8: Loss = 3.1484
# Batch 0: Loss = 0.3063
# Batch 100: Loss = 0.3049
# Batch 200: Loss = 0.3035
# Batch 300: Loss = 0.3021
# Batch 400: Loss = 0.3007
# Batch 500: Loss = 0.2993
# Batch 600: Loss = 0.2980
# Batch 700: Loss = 0.2967
# Batch 800: Loss = 0.2954
# Batch 900: Loss = 0.2941
# Epoch 9: Loss = 3.0009
# Batch 0: Loss = 0.2929
# Batch 100: Loss = 0.2916
# Batch 200: Loss = 0.2904
# Batch 300: Loss = 0.2892
# Batch 400: Loss = 0.2880
# Batch 500: Loss = 0.2869
# Batch 600: Loss = 0.2857
# Batch 700: Loss = 0.2846
# Batch 800: Loss = 0.2834
# Batch 900: Loss = 0.2823
# Epoch 10: Loss = 2.8750
# Batch 0: Loss = 0.2813
# Batch 100: Loss = 0.2802
# Batch 200: Loss = 0.2791
# Batch 300: Loss = 0.2781
# Batch 400: Loss = 0.2771
# Batch 500: Loss = 0.2760
# Batch 600: Loss = 0.2750
# Batch 700: Loss = 0.2740
# Batch 800: Loss = 0.2731
# Batch 900: Loss = 0.2721
# Epoch 11: Loss = 2.7659
# Batch 0: Loss = 0.2711
# Batch 100: Loss = 0.2702
# Batch 200: Loss = 0.2693
# Batch 300: Loss = 0.2683
# Batch 400: Loss = 0.2674
# Batch 500: Loss = 0.2665
# Batch 600: Loss = 0.2656
# Batch 700: Loss = 0.2648
# Batch 800: Loss = 0.2639
# Batch 900: Loss = 0.2631
# Epoch 12: Loss = 2.6703
# Batch 0: Loss = 0.2622
# Batch 100: Loss = 0.2614
# Batch 200: Loss = 0.2605
# Batch 300: Loss = 0.2597
# Batch 400: Loss = 0.2589
# Batch 500: Loss = 0.2581
# Batch 600: Loss = 0.2573
# Batch 700: Loss = 0.2565
# Batch 800: Loss = 0.2558
# Batch 900: Loss = 0.2550
# Epoch 13: Loss = 2.5855
# Batch 0: Loss = 0.2542
# Batch 100: Loss = 0.2535
# Batch 200: Loss = 0.2528
# Batch 300: Loss = 0.2520
# Batch 400: Loss = 0.2513
# Batch 500: Loss = 0.2506
# Batch 600: Loss = 0.2499
# Batch 700: Loss = 0.2492
# Batch 800: Loss = 0.2485
# Batch 900: Loss = 0.2478
# Epoch 14: Loss = 2.5097
# Batch 0: Loss = 0.2471
# Batch 100: Loss = 0.2464
# Batch 200: Loss = 0.2458
# Batch 300: Loss = 0.2451
# Batch 400: Loss = 0.2444
# Batch 500: Loss = 0.2438
# Batch 600: Loss = 0.2432
# Batch 700: Loss = 0.2425
# Batch 800: Loss = 0.2419
# Batch 900: Loss = 0.2413
# Epoch 15: Loss = 2.4415
# Batch 0: Loss = 0.2406
# Batch 100: Loss = 0.2400
# Batch 200: Loss = 0.2394
# Batch 300: Loss = 0.2388
# Batch 400: Loss = 0.2382
# Batch 500: Loss = 0.2376
# Batch 600: Loss = 0.2371
# Batch 700: Loss = 0.2365
# Batch 800: Loss = 0.2359
# Batch 900: Loss = 0.2353
# Epoch 16: Loss = 2.3795
# Batch 0: Loss = 0.2348
# Batch 100: Loss = 0.2342
# Batch 200: Loss = 0.2336
# Batch 300: Loss = 0.2331
# Batch 400: Loss = 0.2326
# Batch 500: Loss = 0.2320
# Batch 600: Loss = 0.2315
# Batch 700: Loss = 0.2309
# Batch 800: Loss = 0.2304
# Batch 900: Loss = 0.2299
# Epoch 17: Loss = 2.3230
# Batch 0: Loss = 0.2294
# Batch 100: Loss = 0.2289
# Batch 200: Loss = 0.2284
# Batch 300: Loss = 0.2279
# Batch 400: Loss = 0.2273
# Batch 500: Loss = 0.2269
# Batch 600: Loss = 0.2264
# Batch 700: Loss = 0.2259
# Batch 800: Loss = 0.2254
# Batch 900: Loss = 0.2249
# Epoch 18: Loss = 2.2712
# Batch 0: Loss = 0.2244
# Batch 100: Loss = 0.2240
# Batch 200: Loss = 0.2235
# Batch 300: Loss = 0.2230
# Batch 400: Loss = 0.2226
# Batch 500: Loss = 0.2221
# Batch 600: Loss = 0.2216
# Batch 700: Loss = 0.2212
# Batch 800: Loss = 0.2207
# Batch 900: Loss = 0.2203
# Epoch 19: Loss = 2.2234
# Batch 0: Loss = 0.2199
# Batch 100: Loss = 0.2194
# Batch 200: Loss = 0.2190
# Batch 300: Loss = 0.2185
# Batch 400: Loss = 0.2181
# Batch 500: Loss = 0.2177
# Batch 600: Loss = 0.2173
# Batch 700: Loss = 0.2168
# Batch 800: Loss = 0.2164
# Batch 900: Loss = 0.2160
# Epoch 20: Loss = 2.1791
# Batch 0: Loss = 0.2156
# Batch 100: Loss = 0.2152
# Batch 200: Loss = 0.2148
# Batch 300: Loss = 0.2144
# Batch 400: Loss = 0.2140
# Batch 500: Loss = 0.2136
# Batch 600: Loss = 0.2132
# Batch 700: Loss = 0.2128
# Batch 800: Loss = 0.2124
# Batch 900: Loss = 0.2120
# Epoch 21: Loss = 2.1380
# Batch 0: Loss = 0.2117
# Batch 100: Loss = 0.2113
# Batch 200: Loss = 0.2109
# Batch 300: Loss = 0.2105
# Batch 400: Loss = 0.2101
# Batch 500: Loss = 0.2098
# Batch 600: Loss = 0.2094
# Batch 700: Loss = 0.2090
# Batch 800: Loss = 0.2087
# Batch 900: Loss = 0.2083
# Epoch 22: Loss = 2.0997
# Batch 0: Loss = 0.2080
# Batch 100: Loss = 0.2076
# Batch 200: Loss = 0.2072
# Batch 300: Loss = 0.2069
# Batch 400: Loss = 0.2065
# Batch 500: Loss = 0.2062
# Batch 600: Loss = 0.2059
# Batch 700: Loss = 0.2055
# Batch 800: Loss = 0.2052
# Batch 900: Loss = 0.2048
# Epoch 23: Loss = 2.0638
# Batch 0: Loss = 0.2045
# Batch 100: Loss = 0.2042
# Batch 200: Loss = 0.2038
# Batch 300: Loss = 0.2035
# Batch 400: Loss = 0.2032
# Batch 500: Loss = 0.2028
# Batch 600: Loss = 0.2025
# Batch 700: Loss = 0.2022
# Batch 800: Loss = 0.2019
# Batch 900: Loss = 0.2016
# Epoch 24: Loss = 2.0302
# Batch 0: Loss = 0.2012
# Batch 100: Loss = 0.2009
# Batch 200: Loss = 0.2006
# Batch 300: Loss = 0.2003
# Batch 400: Loss = 0.2000
# Batch 500: Loss = 0.1997
# Batch 600: Loss = 0.1994
# Batch 700: Loss = 0.1991
# Batch 800: Loss = 0.1988
# Batch 900: Loss = 0.1985
# Epoch 25: Loss = 1.9985
# Batch 0: Loss = 0.1982
# Batch 100: Loss = 0.1979
# Batch 200: Loss = 0.1976
# Batch 300: Loss = 0.1973
# Batch 400: Loss = 0.1970
# Batch 500: Loss = 0.1967
# Batch 600: Loss = 0.1964
# Batch 700: Loss = 0.1961
# Batch 800: Loss = 0.1959
# Batch 900: Loss = 0.1956
# Epoch 26: Loss = 1.9687
# Batch 0: Loss = 0.1953
# Batch 100: Loss = 0.1950
# Batch 200: Loss = 0.1947
# Batch 300: Loss = 0.1945
# Batch 400: Loss = 0.1942
# Batch 500: Loss = 0.1939
# Batch 600: Loss = 0.1936
# Batch 700: Loss = 0.1934
# Batch 800: Loss = 0.1931
# Batch 900: Loss = 0.1928
# Epoch 27: Loss = 1.9405
# Batch 0: Loss = 0.1926
# Batch 100: Loss = 0.1923
# Batch 200: Loss = 0.1920
# Batch 300: Loss = 0.1918
# Batch 400: Loss = 0.1915
# Batch 500: Loss = 0.1912
# Batch 600: Loss = 0.1910
# Batch 700: Loss = 0.1907
# Batch 800: Loss = 0.1905
# Batch 900: Loss = 0.1902
# Epoch 28: Loss = 1.9137
# Batch 0: Loss = 0.1900
# Batch 100: Loss = 0.1897
# Batch 200: Loss = 0.1895
# Batch 300: Loss = 0.1892
# Batch 400: Loss = 0.1890
# Batch 500: Loss = 0.1887
# Batch 600: Loss = 0.1885
# Batch 700: Loss = 0.1882
# Batch 800: Loss = 0.1880
# Batch 900: Loss = 0.1877
# Epoch 29: Loss = 1.8883
# Batch 0: Loss = 0.1875
# Batch 100: Loss = 0.1872
# Batch 200: Loss = 0.1870
# Batch 300: Loss = 0.1868
# Batch 400: Loss = 0.1865
# Batch 500: Loss = 0.1863
# Batch 600: Loss = 0.1861
# Batch 700: Loss = 0.1858
# Batch 800: Loss = 0.1856
# Batch 900: Loss = 0.1854
# Epoch 30: Loss = 1.8642
# Batch 0: Loss = 0.1851
# Batch 100: Loss = 0.1849
# Batch 200: Loss = 0.1847
# Batch 300: Loss = 0.1845
# Batch 400: Loss = 0.1842
# Batch 500: Loss = 0.1840
# Batch 600: Loss = 0.1838
# Batch 700: Loss = 0.1836
# Batch 800: Loss = 0.1833
# Batch 900: Loss = 0.1831
# Epoch 31: Loss = 1.8412
# Batch 0: Loss = 0.1829
# Batch 100: Loss = 0.1827
# Batch 200: Loss = 0.1825
# Batch 300: Loss = 0.1822
# Batch 400: Loss = 0.1820
# Batch 500: Loss = 0.1818
# Batch 600: Loss = 0.1816
# Batch 700: Loss = 0.1814
# Batch 800: Loss = 0.1812
# Batch 900: Loss = 0.1810
# Epoch 32: Loss = 1.8193
# Batch 0: Loss = 0.1808
# Batch 100: Loss = 0.1806
# Batch 200: Loss = 0.1803
# Batch 300: Loss = 0.1801
# Batch 400: Loss = 0.1799
# Batch 500: Loss = 0.1797
# Batch 600: Loss = 0.1795
# Batch 700: Loss = 0.1793
# Batch 800: Loss = 0.1791
# Batch 900: Loss = 0.1789
# Epoch 33: Loss = 1.7983
# Batch 0: Loss = 0.1787
# Batch 100: Loss = 0.1785
# Batch 200: Loss = 0.1783
# Batch 300: Loss = 0.1781
# Batch 400: Loss = 0.1779
# Batch 500: Loss = 0.1777
# Batch 600: Loss = 0.1775
# Batch 700: Loss = 0.1773
# Batch 800: Loss = 0.1771
# Batch 900: Loss = 0.1770
# Epoch 34: Loss = 1.7783
# Batch 0: Loss = 0.1768
# Batch 100: Loss = 0.1766
# Batch 200: Loss = 0.1764
# Batch 300: Loss = 0.1762
# Batch 400: Loss = 0.1760
# Batch 500: Loss = 0.1758
# Batch 600: Loss = 0.1756
# Batch 700: Loss = 0.1754
# Batch 800: Loss = 0.1753
# Batch 900: Loss = 0.1751
# Epoch 35: Loss = 1.7591
# Batch 0: Loss = 0.1749
# Batch 100: Loss = 0.1747
# Batch 200: Loss = 0.1745
# Batch 300: Loss = 0.1743
# Batch 400: Loss = 0.1742
# Batch 500: Loss = 0.1740
# Batch 600: Loss = 0.1738
# Batch 700: Loss = 0.1736
# Batch 800: Loss = 0.1734
# Batch 900: Loss = 0.1733
# Epoch 36: Loss = 1.7406
# Batch 0: Loss = 0.1731
# Batch 100: Loss = 0.1729
# Batch 200: Loss = 0.1727
# Batch 300: Loss = 0.1726
# Batch 400: Loss = 0.1724
# Batch 500: Loss = 0.1722
# Batch 600: Loss = 0.1720
# Batch 700: Loss = 0.1719
# Batch 800: Loss = 0.1717
# Batch 900: Loss = 0.1715
# Epoch 37: Loss = 1.7229
# Batch 0: Loss = 0.1713
# Batch 100: Loss = 0.1712
# Batch 200: Loss = 0.1710
# Batch 300: Loss = 0.1708
# Batch 400: Loss = 0.1707
# Batch 500: Loss = 0.1705
# Batch 600: Loss = 0.1703
# Batch 700: Loss = 0.1702
# Batch 800: Loss = 0.1700
# Batch 900: Loss = 0.1698
# Epoch 38: Loss = 1.7059
# Batch 0: Loss = 0.1697
# Batch 100: Loss = 0.1695
# Batch 200: Loss = 0.1694
# Batch 300: Loss = 0.1692
# Batch 400: Loss = 0.1690
# Batch 500: Loss = 0.1689
# Batch 600: Loss = 0.1687
# Batch 700: Loss = 0.1686
# Batch 800: Loss = 0.1684
# Batch 900: Loss = 0.1682
# Epoch 39: Loss = 1.6895
# Batch 0: Loss = 0.1681
# Batch 100: Loss = 0.1679
# Batch 200: Loss = 0.1678
# Batch 300: Loss = 0.1676
# Batch 400: Loss = 0.1674
# Batch 500: Loss = 0.1673
# Batch 600: Loss = 0.1671
# Batch 700: Loss = 0.1670
# Batch 800: Loss = 0.1668
# Batch 900: Loss = 0.1667
# Epoch 40: Loss = 1.6737
# Batch 0: Loss = 0.1665
# Batch 100: Loss = 0.1664
# Batch 200: Loss = 0.1662
# Batch 300: Loss = 0.1661
# Batch 400: Loss = 0.1659
# Batch 500: Loss = 0.1658
# Batch 600: Loss = 0.1656
# Batch 700: Loss = 0.1655
# Batch 800: Loss = 0.1653
# Batch 900: Loss = 0.1652
# Epoch 41: Loss = 1.6585
# Batch 0: Loss = 0.1650
# Batch 100: Loss = 0.1649
# Batch 200: Loss = 0.1647
# Batch 300: Loss = 0.1646
# Batch 400: Loss = 0.1645
# Batch 500: Loss = 0.1643
# Batch 600: Loss = 0.1642
# Batch 700: Loss = 0.1640
# Batch 800: Loss = 0.1639
# Batch 900: Loss = 0.1637
# Epoch 42: Loss = 1.6438
# Batch 0: Loss = 0.1636
# Batch 100: Loss = 0.1634
# Batch 200: Loss = 0.1633
# Batch 300: Loss = 0.1632
# Batch 400: Loss = 0.1630
# Batch 500: Loss = 0.1629
# Batch 600: Loss = 0.1627
# Batch 700: Loss = 0.1626
# Batch 800: Loss = 0.1625
# Batch 900: Loss = 0.1623
# Epoch 43: Loss = 1.6296
# Batch 0: Loss = 0.1622
# Batch 100: Loss = 0.1621
# Batch 200: Loss = 0.1619
# Batch 300: Loss = 0.1618
# Batch 400: Loss = 0.1617
# Batch 500: Loss = 0.1615
# Batch 600: Loss = 0.1614
# Batch 700: Loss = 0.1612
# Batch 800: Loss = 0.1611
# Batch 900: Loss = 0.1610
# Epoch 44: Loss = 1.6159
# Batch 0: Loss = 0.1608
# Batch 100: Loss = 0.1607
# Batch 200: Loss = 0.1606
# Batch 300: Loss = 0.1605
# Batch 400: Loss = 0.1603
# Batch 500: Loss = 0.1602
# Batch 600: Loss = 0.1601
# Batch 700: Loss = 0.1599
# Batch 800: Loss = 0.1598
# Batch 900: Loss = 0.1597
# Epoch 45: Loss = 1.6026
# Batch 0: Loss = 0.1595
# Batch 100: Loss = 0.1594
# Batch 200: Loss = 0.1593
# Batch 300: Loss = 0.1592
# Batch 400: Loss = 0.1590
# Batch 500: Loss = 0.1589
# Batch 600: Loss = 0.1588
# Batch 700: Loss = 0.1587
# Batch 800: Loss = 0.1585
# Batch 900: Loss = 0.1584
# Epoch 46: Loss = 1.5897
# Batch 0: Loss = 0.1583
# Batch 100: Loss = 0.1582
# Batch 200: Loss = 0.1580
# Batch 300: Loss = 0.1579
# Batch 400: Loss = 0.1578
# Batch 500: Loss = 0.1577
# Batch 600: Loss = 0.1575
# Batch 700: Loss = 0.1574
# Batch 800: Loss = 0.1573
# Batch 900: Loss = 0.1572
# Epoch 47: Loss = 1.5772
# Batch 0: Loss = 0.1570
# Batch 100: Loss = 0.1569
# Batch 200: Loss = 0.1568
# Batch 300: Loss = 0.1567
# Batch 400: Loss = 0.1566
# Batch 500: Loss = 0.1564
# Batch 600: Loss = 0.1563
# Batch 700: Loss = 0.1562
# Batch 800: Loss = 0.1561
# Batch 900: Loss = 0.1560
# Epoch 48: Loss = 1.5651
# Batch 0: Loss = 0.1559
# Batch 100: Loss = 0.1557
# Batch 200: Loss = 0.1556
# Batch 300: Loss = 0.1555
# Batch 400: Loss = 0.1554
# Batch 500: Loss = 0.1553
# Batch 600: Loss = 0.1552
# Batch 700: Loss = 0.1550
# Batch 800: Loss = 0.1549
# Batch 900: Loss = 0.1548
# Epoch 49: Loss = 1.5534
# Batch 0: Loss = 0.1547
# Batch 100: Loss = 0.1546
# Batch 200: Loss = 0.1545
# Batch 300: Loss = 0.1544
# Batch 400: Loss = 0.1542
# Batch 500: Loss = 0.1541
# Batch 600: Loss = 0.1540
# Batch 700: Loss = 0.1539
# Batch 800: Loss = 0.1538
# Batch 900: Loss = 0.1537
# Epoch 50: Loss = 1.5419
# Batch 0: Loss = 0.1536
# Batch 100: Loss = 0.1535
# Batch 200: Loss = 0.1534
# Batch 300: Loss = 0.1532
# Batch 400: Loss = 0.1531
# Batch 500: Loss = 0.1530
# Batch 600: Loss = 0.1529
# Batch 700: Loss = 0.1528
# Batch 800: Loss = 0.1527
# Batch 900: Loss = 0.1526
# Epoch 51: Loss = 1.5309
# Batch 0: Loss = 0.1525
# Batch 100: Loss = 0.1524
# Batch 200: Loss = 0.1523
# Batch 300: Loss = 0.1522
# Batch 400: Loss = 0.1521
# Batch 500: Loss = 0.1520
# Batch 600: Loss = 0.1518
# Batch 700: Loss = 0.1517
# Batch 800: Loss = 0.1516
# Batch 900: Loss = 0.1515
# Epoch 52: Loss = 1.5201
# Batch 0: Loss = 0.1514
# Batch 100: Loss = 0.1513
# Batch 200: Loss = 0.1512
# Batch 300: Loss = 0.1511
# Batch 400: Loss = 0.1510
# Batch 500: Loss = 0.1509
# Batch 600: Loss = 0.1508
# Batch 700: Loss = 0.1507
# Batch 800: Loss = 0.1506
# Batch 900: Loss = 0.1505
# Epoch 53: Loss = 1.5096
# Batch 0: Loss = 0.1504
# Batch 100: Loss = 0.1503
# Batch 200: Loss = 0.1502
# Batch 300: Loss = 0.1501
# Batch 400: Loss = 0.1500
# Batch 500: Loss = 0.1499
# Batch 600: Loss = 0.1498
# Batch 700: Loss = 0.1497
# Batch 800: Loss = 0.1496
# Batch 900: Loss = 0.1495
# Epoch 54: Loss = 1.4994
# Batch 0: Loss = 0.1494
# Batch 100: Loss = 0.1493
# Batch 200: Loss = 0.1492
# Batch 300: Loss = 0.1491
# Batch 400: Loss = 0.1490
# Batch 500: Loss = 0.1489
# Batch 600: Loss = 0.1488
# Batch 700: Loss = 0.1487
# Batch 800: Loss = 0.1486
# Batch 900: Loss = 0.1485
# Epoch 55: Loss = 1.4894
# Batch 0: Loss = 0.1484
# Batch 100: Loss = 0.1483
# Batch 200: Loss = 0.1482
# Batch 300: Loss = 0.1481
# Batch 400: Loss = 0.1480
# Batch 500: Loss = 0.1479
# Batch 600: Loss = 0.1478
# Batch 700: Loss = 0.1477
# Batch 800: Loss = 0.1476
# Batch 900: Loss = 0.1475
# Epoch 56: Loss = 1.4798
# Batch 0: Loss = 0.1475
# Batch 100: Loss = 0.1474
# Batch 200: Loss = 0.1473
# Batch 300: Loss = 0.1472
# Batch 400: Loss = 0.1471
# Batch 500: Loss = 0.1470
# Batch 600: Loss = 0.1469
# Batch 700: Loss = 0.1468
# Batch 800: Loss = 0.1467
# Batch 900: Loss = 0.1466
# Epoch 57: Loss = 1.4703
# Batch 0: Loss = 0.1465
# Batch 100: Loss = 0.1464
# Batch 200: Loss = 0.1463
# Batch 300: Loss = 0.1462
# Batch 400: Loss = 0.1462
# Batch 500: Loss = 0.1461
# Batch 600: Loss = 0.1460
# Batch 700: Loss = 0.1459
# Batch 800: Loss = 0.1458
# Batch 900: Loss = 0.1457
# Epoch 58: Loss = 1.4611
# Batch 0: Loss = 0.1456
# Batch 100: Loss = 0.1455
# Batch 200: Loss = 0.1454
# Batch 300: Loss = 0.1453
# Batch 400: Loss = 0.1453
# Batch 500: Loss = 0.1452
# Batch 600: Loss = 0.1451
# Batch 700: Loss = 0.1450
# Batch 800: Loss = 0.1449
# Batch 900: Loss = 0.1448
# Epoch 59: Loss = 1.4521
# Batch 0: Loss = 0.1447
# Batch 100: Loss = 0.1446
# Batch 200: Loss = 0.1446
# Batch 300: Loss = 0.1445
# Batch 400: Loss = 0.1444
# Batch 500: Loss = 0.1443
# Batch 600: Loss = 0.1442
# Batch 700: Loss = 0.1441
# Batch 800: Loss = 0.1440
# Batch 900: Loss = 0.1439
# Epoch 60: Loss = 1.4434
# Batch 0: Loss = 0.1439
# Batch 100: Loss = 0.1438
# Batch 200: Loss = 0.1437
# Batch 300: Loss = 0.1436
# Batch 400: Loss = 0.1435
# Batch 500: Loss = 0.1434
# Batch 600: Loss = 0.1434
# Batch 700: Loss = 0.1433
# Batch 800: Loss = 0.1432
# Batch 900: Loss = 0.1431
# Epoch 61: Loss = 1.4348
# Batch 0: Loss = 0.1430
# Batch 100: Loss = 0.1429
# Batch 200: Loss = 0.1428
# Batch 300: Loss = 0.1428
# Batch 400: Loss = 0.1427
# Batch 500: Loss = 0.1426
# Batch 600: Loss = 0.1425
# Batch 700: Loss = 0.1424
# Batch 800: Loss = 0.1424
# Batch 900: Loss = 0.1423
# Epoch 62: Loss = 1.4264
# Batch 0: Loss = 0.1422
# Batch 100: Loss = 0.1421
# Batch 200: Loss = 0.1420
# Batch 300: Loss = 0.1419
# Batch 400: Loss = 0.1419
# Batch 500: Loss = 0.1418
# Batch 600: Loss = 0.1417
# Batch 700: Loss = 0.1416
# Batch 800: Loss = 0.1415
# Batch 900: Loss = 0.1415
# Epoch 63: Loss = 1.4182
# Batch 0: Loss = 0.1414
# Batch 100: Loss = 0.1413
# Batch 200: Loss = 0.1412
# Batch 300: Loss = 0.1411
# Batch 400: Loss = 0.1411
# Batch 500: Loss = 0.1410
# Batch 600: Loss = 0.1409
# Batch 700: Loss = 0.1408
# Batch 800: Loss = 0.1407
# Batch 900: Loss = 0.1407
# Epoch 64: Loss = 1.4102
# Batch 0: Loss = 0.1406
# Batch 100: Loss = 0.1405
# Batch 200: Loss = 0.1404
# Batch 300: Loss = 0.1404
# Batch 400: Loss = 0.1403
# Batch 500: Loss = 0.1402
# Batch 600: Loss = 0.1401
# Batch 700: Loss = 0.1400
# Batch 800: Loss = 0.1400
# Batch 900: Loss = 0.1399
# Epoch 65: Loss = 1.4024
# Batch 0: Loss = 0.1398
# Batch 100: Loss = 0.1397
# Batch 200: Loss = 0.1397
# Batch 300: Loss = 0.1396
# Batch 400: Loss = 0.1395
# Batch 500: Loss = 0.1394
# Batch 600: Loss = 0.1394
# Batch 700: Loss = 0.1393
# Batch 800: Loss = 0.1392
# Batch 900: Loss = 0.1391
# Epoch 66: Loss = 1.3948
# Batch 0: Loss = 0.1391
# Batch 100: Loss = 0.1390
# Batch 200: Loss = 0.1389
# Batch 300: Loss = 0.1388
# Batch 400: Loss = 0.1388
# Batch 500: Loss = 0.1387
# Batch 600: Loss = 0.1386
# Batch 700: Loss = 0.1385
# Batch 800: Loss = 0.1385
# Batch 900: Loss = 0.1384
# Epoch 67: Loss = 1.3873
# Batch 0: Loss = 0.1383
# Batch 100: Loss = 0.1382
# Batch 200: Loss = 0.1382
# Batch 300: Loss = 0.1381
# Batch 400: Loss = 0.1380
# Batch 500: Loss = 0.1380
# Batch 600: Loss = 0.1379
# Batch 700: Loss = 0.1378
# Batch 800: Loss = 0.1377
# Batch 900: Loss = 0.1377
# Epoch 68: Loss = 1.3799
# Batch 0: Loss = 0.1376
# Batch 100: Loss = 0.1375
# Batch 200: Loss = 0.1375
# Batch 300: Loss = 0.1374
# Batch 400: Loss = 0.1373
# Batch 500: Loss = 0.1372
# Batch 600: Loss = 0.1372
# Batch 700: Loss = 0.1371
# Batch 800: Loss = 0.1370
# Batch 900: Loss = 0.1370
# Epoch 69: Loss = 1.3728
# Batch 0: Loss = 0.1369
# Batch 100: Loss = 0.1368
# Batch 200: Loss = 0.1367
# Batch 300: Loss = 0.1367
# Batch 400: Loss = 0.1366
# Batch 500: Loss = 0.1365
# Batch 600: Loss = 0.1365
# Batch 700: Loss = 0.1364
# Batch 800: Loss = 0.1363
# Batch 900: Loss = 0.1363
# Epoch 70: Loss = 1.3657
# Batch 0: Loss = 0.1362
# Batch 100: Loss = 0.1361
# Batch 200: Loss = 0.1361
# Batch 300: Loss = 0.1360
# Batch 400: Loss = 0.1359
# Batch 500: Loss = 0.1358
# Batch 600: Loss = 0.1358
# Batch 700: Loss = 0.1357
# Batch 800: Loss = 0.1356
# Batch 900: Loss = 0.1356
# Epoch 71: Loss = 1.3588
# Batch 0: Loss = 0.1355
# Batch 100: Loss = 0.1354
# Batch 200: Loss = 0.1354
# Batch 300: Loss = 0.1353
# Batch 400: Loss = 0.1352
# Batch 500: Loss = 0.1352
# Batch 600: Loss = 0.1351
# Batch 700: Loss = 0.1350
# Batch 800: Loss = 0.1350
# Batch 900: Loss = 0.1349
# Epoch 72: Loss = 1.3521
# Batch 0: Loss = 0.1348
# Batch 100: Loss = 0.1348
# Batch 200: Loss = 0.1347
# Batch 300: Loss = 0.1346
# Batch 400: Loss = 0.1346
# Batch 500: Loss = 0.1345
# Batch 600: Loss = 0.1344
# Batch 700: Loss = 0.1344
# Batch 800: Loss = 0.1343
# Batch 900: Loss = 0.1342
# Epoch 73: Loss = 1.3454
# Batch 0: Loss = 0.1342
# Batch 100: Loss = 0.1341
# Batch 200: Loss = 0.1341
# Batch 300: Loss = 0.1340
# Batch 400: Loss = 0.1339
# Batch 500: Loss = 0.1339
# Batch 600: Loss = 0.1338
# Batch 700: Loss = 0.1337
# Batch 800: Loss = 0.1337
# Batch 900: Loss = 0.1336
# Epoch 74: Loss = 1.3389
# Batch 0: Loss = 0.1335
# Batch 100: Loss = 0.1335
# Batch 200: Loss = 0.1334
# Batch 300: Loss = 0.1333
# Batch 400: Loss = 0.1333
# Batch 500: Loss = 0.1332
# Batch 600: Loss = 0.1332
# Batch 700: Loss = 0.1331
# Batch 800: Loss = 0.1330
# Batch 900: Loss = 0.1330
# Epoch 75: Loss = 1.3325
# Batch 0: Loss = 0.1329
# Batch 100: Loss = 0.1328
# Batch 200: Loss = 0.1328
# Batch 300: Loss = 0.1327
# Batch 400: Loss = 0.1327
# Batch 500: Loss = 0.1326
# Batch 600: Loss = 0.1325
# Batch 700: Loss = 0.1325
# Batch 800: Loss = 0.1324
# Batch 900: Loss = 0.1324
# Epoch 76: Loss = 1.3263
# Batch 0: Loss = 0.1323
# Batch 100: Loss = 0.1322
# Batch 200: Loss = 0.1322
# Batch 300: Loss = 0.1321
# Batch 400: Loss = 0.1320
# Batch 500: Loss = 0.1320
# Batch 600: Loss = 0.1319
# Batch 700: Loss = 0.1319
# Batch 800: Loss = 0.1318
# Batch 900: Loss = 0.1317
# Epoch 77: Loss = 1.3201
# Batch 0: Loss = 0.1317
# Batch 100: Loss = 0.1316
# Batch 200: Loss = 0.1316
# Batch 300: Loss = 0.1315
# Batch 400: Loss = 0.1314
# Batch 500: Loss = 0.1314
# Batch 600: Loss = 0.1313
# Batch 700: Loss = 0.1313
# Batch 800: Loss = 0.1312
# Batch 900: Loss = 0.1311
# Epoch 78: Loss = 1.3141
# Batch 0: Loss = 0.1311
# Batch 100: Loss = 0.1310
# Batch 200: Loss = 0.1310
# Batch 300: Loss = 0.1309
# Batch 400: Loss = 0.1308
# Batch 500: Loss = 0.1308
# Batch 600: Loss = 0.1307
# Batch 700: Loss = 0.1307
# Batch 800: Loss = 0.1306
# Batch 900: Loss = 0.1306
# Epoch 79: Loss = 1.3082
# Batch 0: Loss = 0.1305
# Batch 100: Loss = 0.1304
# Batch 200: Loss = 0.1304
# Batch 300: Loss = 0.1303
# Batch 400: Loss = 0.1303
# Batch 500: Loss = 0.1302
# Batch 600: Loss = 0.1301
# Batch 700: Loss = 0.1301
# Batch 800: Loss = 0.1300
# Batch 900: Loss = 0.1300
# Epoch 80: Loss = 1.3024
# Batch 0: Loss = 0.1299
# Batch 100: Loss = 0.1299
# Batch 200: Loss = 0.1298
# Batch 300: Loss = 0.1297
# Batch 400: Loss = 0.1297
# Batch 500: Loss = 0.1296
# Batch 600: Loss = 0.1296
# Batch 700: Loss = 0.1295
# Batch 800: Loss = 0.1295
# Batch 900: Loss = 0.1294
# Epoch 81: Loss = 1.2966
# Batch 0: Loss = 0.1294
# Batch 100: Loss = 0.1293
# Batch 200: Loss = 0.1292
# Batch 300: Loss = 0.1292
# Batch 400: Loss = 0.1291
# Batch 500: Loss = 0.1291
# Batch 600: Loss = 0.1290
# Batch 700: Loss = 0.1290
# Batch 800: Loss = 0.1289
# Batch 900: Loss = 0.1289
# Epoch 82: Loss = 1.2910
# Batch 0: Loss = 0.1288
# Batch 100: Loss = 0.1287
# Batch 200: Loss = 0.1287
# Batch 300: Loss = 0.1286
# Batch 400: Loss = 0.1286
# Batch 500: Loss = 0.1285
# Batch 600: Loss = 0.1285
# Batch 700: Loss = 0.1284
# Batch 800: Loss = 0.1284
# Batch 900: Loss = 0.1283
# Epoch 83: Loss = 1.2855
# Batch 0: Loss = 0.1282
# Batch 100: Loss = 0.1282
# Batch 200: Loss = 0.1281
# Batch 300: Loss = 0.1281
# Batch 400: Loss = 0.1280
# Batch 500: Loss = 0.1280
# Batch 600: Loss = 0.1279
# Batch 700: Loss = 0.1279
# Batch 800: Loss = 0.1278
# Batch 900: Loss = 0.1278
# Epoch 84: Loss = 1.2800
# Batch 0: Loss = 0.1277
# Batch 100: Loss = 0.1277
# Batch 200: Loss = 0.1276
# Batch 300: Loss = 0.1275
# Batch 400: Loss = 0.1275
# Batch 500: Loss = 0.1274
# Batch 600: Loss = 0.1274
# Batch 700: Loss = 0.1273
# Batch 800: Loss = 0.1273
# Batch 900: Loss = 0.1272
# Epoch 85: Loss = 1.2747
# Batch 0: Loss = 0.1272
# Batch 100: Loss = 0.1271
# Batch 200: Loss = 0.1271
# Batch 300: Loss = 0.1270
# Batch 400: Loss = 0.1270
# Batch 500: Loss = 0.1269
# Batch 600: Loss = 0.1269
# Batch 700: Loss = 0.1268
# Batch 800: Loss = 0.1268
# Batch 900: Loss = 0.1267
# Epoch 86: Loss = 1.2694
# Batch 0: Loss = 0.1267
# Batch 100: Loss = 0.1266
# Batch 200: Loss = 0.1266
# Batch 300: Loss = 0.1265
# Batch 400: Loss = 0.1265
# Batch 500: Loss = 0.1264
# Batch 600: Loss = 0.1264
# Batch 700: Loss = 0.1263
# Batch 800: Loss = 0.1262
# Batch 900: Loss = 0.1262
# Epoch 87: Loss = 1.2643
# Batch 0: Loss = 0.1261
# Batch 100: Loss = 0.1261
# Batch 200: Loss = 0.1260
# Batch 300: Loss = 0.1260
# Batch 400: Loss = 0.1259
# Batch 500: Loss = 0.1259
# Batch 600: Loss = 0.1258
# Batch 700: Loss = 0.1258
# Batch 800: Loss = 0.1257
# Batch 900: Loss = 0.1257
# Epoch 88: Loss = 1.2592
# Batch 0: Loss = 0.1256
# Batch 100: Loss = 0.1256
# Batch 200: Loss = 0.1255
# Batch 300: Loss = 0.1255
# Batch 400: Loss = 0.1254
# Batch 500: Loss = 0.1254
# Batch 600: Loss = 0.1253
# Batch 700: Loss = 0.1253
# Batch 800: Loss = 0.1252
# Batch 900: Loss = 0.1252
# Epoch 89: Loss = 1.2542
# Batch 0: Loss = 0.1251
# Batch 100: Loss = 0.1251
# Batch 200: Loss = 0.1250
# Batch 300: Loss = 0.1250
# Batch 400: Loss = 0.1249
# Batch 500: Loss = 0.1249
# Batch 600: Loss = 0.1249
# Batch 700: Loss = 0.1248
# Batch 800: Loss = 0.1248
# Batch 900: Loss = 0.1247
# Epoch 90: Loss = 1.2492
# Batch 0: Loss = 0.1247
# Batch 100: Loss = 0.1246
# Batch 200: Loss = 0.1246
# Batch 300: Loss = 0.1245
# Batch 400: Loss = 0.1245
# Batch 500: Loss = 0.1244
# Batch 600: Loss = 0.1244
# Batch 700: Loss = 0.1243
# Batch 800: Loss = 0.1243
# Batch 900: Loss = 0.1242
# Epoch 91: Loss = 1.2444
# Batch 0: Loss = 0.1242
# Batch 100: Loss = 0.1241
# Batch 200: Loss = 0.1241
# Batch 300: Loss = 0.1240
# Batch 400: Loss = 0.1240
# Batch 500: Loss = 0.1239
# Batch 600: Loss = 0.1239
# Batch 700: Loss = 0.1238
# Batch 800: Loss = 0.1238
# Batch 900: Loss = 0.1237
# Epoch 92: Loss = 1.2396
# Batch 0: Loss = 0.1237
# Batch 100: Loss = 0.1237
# Batch 200: Loss = 0.1236
# Batch 300: Loss = 0.1236
# Batch 400: Loss = 0.1235
# Batch 500: Loss = 0.1235
# Batch 600: Loss = 0.1234
# Batch 700: Loss = 0.1234
# Batch 800: Loss = 0.1233
# Batch 900: Loss = 0.1233
# Epoch 93: Loss = 1.2349
# Batch 0: Loss = 0.1232
# Batch 100: Loss = 0.1232
# Batch 200: Loss = 0.1231
# Batch 300: Loss = 0.1231
# Batch 400: Loss = 0.1230
# Batch 500: Loss = 0.1230
# Batch 600: Loss = 0.1230
# Batch 700: Loss = 0.1229
# Batch 800: Loss = 0.1229
# Batch 900: Loss = 0.1228
# Epoch 94: Loss = 1.2303
# Batch 0: Loss = 0.1228
# Batch 100: Loss = 0.1227
# Batch 200: Loss = 0.1227
# Batch 300: Loss = 0.1226
# Batch 400: Loss = 0.1226
# Batch 500: Loss = 0.1225
# Batch 600: Loss = 0.1225
# Batch 700: Loss = 0.1225
# Batch 800: Loss = 0.1224
# Batch 900: Loss = 0.1224
# Epoch 95: Loss = 1.2257
# Batch 0: Loss = 0.1223
# Batch 100: Loss = 0.1223
# Batch 200: Loss = 0.1222
# Batch 300: Loss = 0.1222
# Batch 400: Loss = 0.1221
# Batch 500: Loss = 0.1221
# Batch 600: Loss = 0.1221
# Batch 700: Loss = 0.1220
# Batch 800: Loss = 0.1220
# Batch 900: Loss = 0.1219
# Epoch 96: Loss = 1.2212
# Batch 0: Loss = 0.1219
# Batch 100: Loss = 0.1218
# Batch 200: Loss = 0.1218
# Batch 300: Loss = 0.1217
# Batch 400: Loss = 0.1217
# Batch 500: Loss = 0.1217
# Batch 600: Loss = 0.1216
# Batch 700: Loss = 0.1216
# Batch 800: Loss = 0.1215
# Batch 900: Loss = 0.1215
# Epoch 97: Loss = 1.2167
# Batch 0: Loss = 0.1214
# Batch 100: Loss = 0.1214
# Batch 200: Loss = 0.1213
# Batch 300: Loss = 0.1213
# Batch 400: Loss = 0.1213
# Batch 500: Loss = 0.1212
# Batch 600: Loss = 0.1212
# Batch 700: Loss = 0.1211
# Batch 800: Loss = 0.1211
# Batch 900: Loss = 0.1210
# Epoch 98: Loss = 1.2124
# Batch 0: Loss = 0.1210
# Batch 100: Loss = 0.1210
# Batch 200: Loss = 0.1209
# Batch 300: Loss = 0.1209
# Batch 400: Loss = 0.1208
# Batch 500: Loss = 0.1208
# Batch 600: Loss = 0.1207
# Batch 700: Loss = 0.1207
# Batch 800: Loss = 0.1207
# Batch 900: Loss = 0.1206
# Epoch 99: Loss = 1.2080
# Batch 0: Loss = 0.1206
# Batch 100: Loss = 0.1205
# Batch 200: Loss = 0.1205
# Batch 300: Loss = 0.1204
# Batch 400: Loss = 0.1204
# Batch 500: Loss = 0.1204
# Batch 600: Loss = 0.1203
# Batch 700: Loss = 0.1203
# Batch 800: Loss = 0.1202
# Batch 900: Loss = 0.1202
# Epoch 100: Loss = 1.2038

# %% [markdown]
# Using mini batches and randomization definitely helped optimize the loss better in the same #steps. What would happen if we use momemtum factor?

# %%
# torch.optim.SGD
num_iterations = 100
learning_rate = 0.1

w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)

optimizer = SGD([w, b], lr=learning_rate, momentum=0.9)

for step in range(num_iterations):

    # shuffle X, Y
    perm = torch.randperm(m)
    X_shuffled, Y_shuffled = X[:, perm], Y[:, perm]

    epoch_loss = 0.0

    # use mini-batches
    for batch in range(0, m, 100):

        X_batch, Y_batch = X_shuffled[:, batch:batch+100], Y_shuffled[:, batch:batch+100]

        z = w.T @ X_shuffled + b
        a = sigmoid(z)

        loss = binary_cross_entropy_loss(a, Y_shuffled)
        epoch_loss += loss

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        print(f"Batch {batch}: Loss = {loss.item():.4f}")

    print(f"Epoch {step+1}: Loss = {epoch_loss.item():.4f}")
# Out:
# Batch 0: Loss = 0.6931
# Batch 100: Loss = 0.6777
# Batch 200: Loss = 0.6498
# Batch 300: Loss = 0.6131
# Batch 400: Loss = 0.5712
# Batch 500: Loss = 0.5277
# Batch 600: Loss = 0.4852
# Batch 700: Loss = 0.4454
# Batch 800: Loss = 0.4093
# Batch 900: Loss = 0.3773
# Epoch 1: Loss = 5.4499
# Batch 0: Loss = 0.3491
# Batch 100: Loss = 0.3247
# Batch 200: Loss = 0.3035
# Batch 300: Loss = 0.2851
# Batch 400: Loss = 0.2691
# Batch 500: Loss = 0.2552
# Batch 600: Loss = 0.2430
# Batch 700: Loss = 0.2324
# Batch 800: Loss = 0.2230
# Batch 900: Loss = 0.2148
# Epoch 2: Loss = 2.6998
# Batch 0: Loss = 0.2074
# Batch 100: Loss = 0.2008
# Batch 200: Loss = 0.1950
# Batch 300: Loss = 0.1897
# Batch 400: Loss = 0.1850
# Batch 500: Loss = 0.1807
# Batch 600: Loss = 0.1767
# Batch 700: Loss = 0.1732
# Batch 800: Loss = 0.1699
# Batch 900: Loss = 0.1669
# Epoch 3: Loss = 1.8454
# Batch 0: Loss = 0.1642
# Batch 100: Loss = 0.1616
# Batch 200: Loss = 0.1593
# Batch 300: Loss = 0.1571
# Batch 400: Loss = 0.1550
# Batch 500: Loss = 0.1531
# Batch 600: Loss = 0.1514
# Batch 700: Loss = 0.1497
# Batch 800: Loss = 0.1481
# Batch 900: Loss = 0.1466
# Epoch 4: Loss = 1.5462
# Batch 0: Loss = 0.1452
# Batch 100: Loss = 0.1439
# Batch 200: Loss = 0.1427
# Batch 300: Loss = 0.1415
# Batch 400: Loss = 0.1403
# Batch 500: Loss = 0.1393
# Batch 600: Loss = 0.1382
# Batch 700: Loss = 0.1372
# Batch 800: Loss = 0.1363
# Batch 900: Loss = 0.1354
# Epoch 5: Loss = 1.4000
# Batch 0: Loss = 0.1345
# Batch 100: Loss = 0.1336
# Batch 200: Loss = 0.1328
# Batch 300: Loss = 0.1320
# Batch 400: Loss = 0.1313
# Batch 500: Loss = 0.1305
# Batch 600: Loss = 0.1298
# Batch 700: Loss = 0.1291
# Batch 800: Loss = 0.1285
# Batch 900: Loss = 0.1278
# Epoch 6: Loss = 1.3101
# Batch 0: Loss = 0.1272
# Batch 100: Loss = 0.1266
# Batch 200: Loss = 0.1260
# Batch 300: Loss = 0.1254
# Batch 400: Loss = 0.1248
# Batch 500: Loss = 0.1242
# Batch 600: Loss = 0.1237
# Batch 700: Loss = 0.1232
# Batch 800: Loss = 0.1226
# Batch 900: Loss = 0.1221
# Epoch 7: Loss = 1.2458
# Batch 0: Loss = 0.1216
# Batch 100: Loss = 0.1211
# Batch 200: Loss = 0.1207
# Batch 300: Loss = 0.1202
# Batch 400: Loss = 0.1197
# Batch 500: Loss = 0.1193
# Batch 600: Loss = 0.1188
# Batch 700: Loss = 0.1184
# Batch 800: Loss = 0.1179
# Batch 900: Loss = 0.1175
# Epoch 8: Loss = 1.1952
# Batch 0: Loss = 0.1171
# Batch 100: Loss = 0.1167
# Batch 200: Loss = 0.1163
# Batch 300: Loss = 0.1159
# Batch 400: Loss = 0.1155
# Batch 500: Loss = 0.1151
# Batch 600: Loss = 0.1147
# Batch 700: Loss = 0.1143
# Batch 800: Loss = 0.1140
# Batch 900: Loss = 0.1136
# Epoch 9: Loss = 1.1532
# Batch 0: Loss = 0.1133
# Batch 100: Loss = 0.1129
# Batch 200: Loss = 0.1125
# Batch 300: Loss = 0.1122
# Batch 400: Loss = 0.1119
# Batch 500: Loss = 0.1115
# Batch 600: Loss = 0.1112
# Batch 700: Loss = 0.1109
# Batch 800: Loss = 0.1105
# Batch 900: Loss = 0.1102
# Epoch 10: Loss = 1.1171
# Batch 0: Loss = 0.1099
# Batch 100: Loss = 0.1096
# Batch 200: Loss = 0.1093
# Batch 300: Loss = 0.1090
# Batch 400: Loss = 0.1087
# Batch 500: Loss = 0.1084
# Batch 600: Loss = 0.1081
# Batch 700: Loss = 0.1078
# Batch 800: Loss = 0.1075
# Batch 900: Loss = 0.1072
# Epoch 11: Loss = 1.0854
# Batch 0: Loss = 0.1069
# Batch 100: Loss = 0.1067
# Batch 200: Loss = 0.1064
# Batch 300: Loss = 0.1061
# Batch 400: Loss = 0.1058
# Batch 500: Loss = 0.1056
# Batch 600: Loss = 0.1053
# Batch 700: Loss = 0.1051
# Batch 800: Loss = 0.1048
# Batch 900: Loss = 0.1045
# Epoch 12: Loss = 1.0573
# Batch 0: Loss = 0.1043
# Batch 100: Loss = 0.1040
# Batch 200: Loss = 0.1038
# Batch 300: Loss = 0.1035
# Batch 400: Loss = 0.1033
# Batch 500: Loss = 0.1031
# Batch 600: Loss = 0.1028
# Batch 700: Loss = 0.1026
# Batch 800: Loss = 0.1024
# Batch 900: Loss = 0.1021
# Epoch 13: Loss = 1.0319
# Batch 0: Loss = 0.1019
# Batch 100: Loss = 0.1017
# Batch 200: Loss = 0.1014
# Batch 300: Loss = 0.1012
# Batch 400: Loss = 0.1010
# Batch 500: Loss = 0.1008
# Batch 600: Loss = 0.1006
# Batch 700: Loss = 0.1003
# Batch 800: Loss = 0.1001
# Batch 900: Loss = 0.0999
# Epoch 14: Loss = 1.0089
# Batch 0: Loss = 0.0997
# Batch 100: Loss = 0.0995
# Batch 200: Loss = 0.0993
# Batch 300: Loss = 0.0991
# Batch 400: Loss = 0.0989
# Batch 500: Loss = 0.0987
# Batch 600: Loss = 0.0985
# Batch 700: Loss = 0.0983
# Batch 800: Loss = 0.0981
# Batch 900: Loss = 0.0979
# Epoch 15: Loss = 0.9878
# Batch 0: Loss = 0.0977
# Batch 100: Loss = 0.0975
# Batch 200: Loss = 0.0973
# Batch 300: Loss = 0.0971
# Batch 400: Loss = 0.0969
# Batch 500: Loss = 0.0967
# Batch 600: Loss = 0.0966
# Batch 700: Loss = 0.0964
# Batch 800: Loss = 0.0962
# Batch 900: Loss = 0.0960
# Epoch 16: Loss = 0.9685
# Batch 0: Loss = 0.0958
# Batch 100: Loss = 0.0957
# Batch 200: Loss = 0.0955
# Batch 300: Loss = 0.0953
# Batch 400: Loss = 0.0951
# Batch 500: Loss = 0.0950
# Batch 600: Loss = 0.0948
# Batch 700: Loss = 0.0946
# Batch 800: Loss = 0.0945
# Batch 900: Loss = 0.0943
# Epoch 17: Loss = 0.9506
# Batch 0: Loss = 0.0941
# Batch 100: Loss = 0.0940
# Batch 200: Loss = 0.0938
# Batch 300: Loss = 0.0936
# Batch 400: Loss = 0.0935
# Batch 500: Loss = 0.0933
# Batch 600: Loss = 0.0932
# Batch 700: Loss = 0.0930
# Batch 800: Loss = 0.0928
# Batch 900: Loss = 0.0927
# Epoch 18: Loss = 0.9340
# Batch 0: Loss = 0.0925
# Batch 100: Loss = 0.0924
# Batch 200: Loss = 0.0922
# Batch 300: Loss = 0.0921
# Batch 400: Loss = 0.0919
# Batch 500: Loss = 0.0918
# Batch 600: Loss = 0.0916
# Batch 700: Loss = 0.0915
# Batch 800: Loss = 0.0913
# Batch 900: Loss = 0.0912
# Epoch 19: Loss = 0.9185
# Batch 0: Loss = 0.0910
# Batch 100: Loss = 0.0909
# Batch 200: Loss = 0.0907
# Batch 300: Loss = 0.0906
# Batch 400: Loss = 0.0905
# Batch 500: Loss = 0.0903
# Batch 600: Loss = 0.0902
# Batch 700: Loss = 0.0900
# Batch 800: Loss = 0.0899
# Batch 900: Loss = 0.0898
# Epoch 20: Loss = 0.9039
# Batch 0: Loss = 0.0896
# Batch 100: Loss = 0.0895
# Batch 200: Loss = 0.0894
# Batch 300: Loss = 0.0892
# Batch 400: Loss = 0.0891
# Batch 500: Loss = 0.0890
# Batch 600: Loss = 0.0888
# Batch 700: Loss = 0.0887
# Batch 800: Loss = 0.0886
# Batch 900: Loss = 0.0884
# Epoch 21: Loss = 0.8903
# Batch 0: Loss = 0.0883
# Batch 100: Loss = 0.0882
# Batch 200: Loss = 0.0881
# Batch 300: Loss = 0.0879
# Batch 400: Loss = 0.0878
# Batch 500: Loss = 0.0877
# Batch 600: Loss = 0.0876
# Batch 700: Loss = 0.0874
# Batch 800: Loss = 0.0873
# Batch 900: Loss = 0.0872
# Epoch 22: Loss = 0.8774
# Batch 0: Loss = 0.0871
# Batch 100: Loss = 0.0869
# Batch 200: Loss = 0.0868
# Batch 300: Loss = 0.0867
# Batch 400: Loss = 0.0866
# Batch 500: Loss = 0.0865
# Batch 600: Loss = 0.0864
# Batch 700: Loss = 0.0862
# Batch 800: Loss = 0.0861
# Batch 900: Loss = 0.0860
# Epoch 23: Loss = 0.8653
# Batch 0: Loss = 0.0859
# Batch 100: Loss = 0.0858
# Batch 200: Loss = 0.0857
# Batch 300: Loss = 0.0855
# Batch 400: Loss = 0.0854
# Batch 500: Loss = 0.0853
# Batch 600: Loss = 0.0852
# Batch 700: Loss = 0.0851
# Batch 800: Loss = 0.0850
# Batch 900: Loss = 0.0849
# Epoch 24: Loss = 0.8538
# Batch 0: Loss = 0.0848
# Batch 100: Loss = 0.0847
# Batch 200: Loss = 0.0846
# Batch 300: Loss = 0.0844
# Batch 400: Loss = 0.0843
# Batch 500: Loss = 0.0842
# Batch 600: Loss = 0.0841
# Batch 700: Loss = 0.0840
# Batch 800: Loss = 0.0839
# Batch 900: Loss = 0.0838
# Epoch 25: Loss = 0.8429
# Batch 0: Loss = 0.0837
# Batch 100: Loss = 0.0836
# Batch 200: Loss = 0.0835
# Batch 300: Loss = 0.0834
# Batch 400: Loss = 0.0833
# Batch 500: Loss = 0.0832
# Batch 600: Loss = 0.0831
# Batch 700: Loss = 0.0830
# Batch 800: Loss = 0.0829
# Batch 900: Loss = 0.0828
# Epoch 26: Loss = 0.8326
# Batch 0: Loss = 0.0827
# Batch 100: Loss = 0.0826
# Batch 200: Loss = 0.0825
# Batch 300: Loss = 0.0824
# Batch 400: Loss = 0.0823
# Batch 500: Loss = 0.0822
# Batch 600: Loss = 0.0821
# Batch 700: Loss = 0.0820
# Batch 800: Loss = 0.0819
# Batch 900: Loss = 0.0818
# Epoch 27: Loss = 0.8227
# Batch 0: Loss = 0.0817
# Batch 100: Loss = 0.0816
# Batch 200: Loss = 0.0816
# Batch 300: Loss = 0.0815
# Batch 400: Loss = 0.0814
# Batch 500: Loss = 0.0813
# Batch 600: Loss = 0.0812
# Batch 700: Loss = 0.0811
# Batch 800: Loss = 0.0810
# Batch 900: Loss = 0.0809
# Epoch 28: Loss = 0.8132
# Batch 0: Loss = 0.0808
# Batch 100: Loss = 0.0807
# Batch 200: Loss = 0.0806
# Batch 300: Loss = 0.0806
# Batch 400: Loss = 0.0805
# Batch 500: Loss = 0.0804
# Batch 600: Loss = 0.0803
# Batch 700: Loss = 0.0802
# Batch 800: Loss = 0.0801
# Batch 900: Loss = 0.0800
# Epoch 29: Loss = 0.8042
# Batch 0: Loss = 0.0799
# Batch 100: Loss = 0.0799
# Batch 200: Loss = 0.0798
# Batch 300: Loss = 0.0797
# Batch 400: Loss = 0.0796
# Batch 500: Loss = 0.0795
# Batch 600: Loss = 0.0794
# Batch 700: Loss = 0.0793
# Batch 800: Loss = 0.0793
# Batch 900: Loss = 0.0792
# Epoch 30: Loss = 0.7956
# Batch 0: Loss = 0.0791
# Batch 100: Loss = 0.0790
# Batch 200: Loss = 0.0789
# Batch 300: Loss = 0.0789
# Batch 400: Loss = 0.0788
# Batch 500: Loss = 0.0787
# Batch 600: Loss = 0.0786
# Batch 700: Loss = 0.0785
# Batch 800: Loss = 0.0785
# Batch 900: Loss = 0.0784
# Epoch 31: Loss = 0.7873
# Batch 0: Loss = 0.0783
# Batch 100: Loss = 0.0782
# Batch 200: Loss = 0.0781
# Batch 300: Loss = 0.0781
# Batch 400: Loss = 0.0780
# Batch 500: Loss = 0.0779
# Batch 600: Loss = 0.0778
# Batch 700: Loss = 0.0777
# Batch 800: Loss = 0.0777
# Batch 900: Loss = 0.0776
# Epoch 32: Loss = 0.7794
# Batch 0: Loss = 0.0775
# Batch 100: Loss = 0.0774
# Batch 200: Loss = 0.0774
# Batch 300: Loss = 0.0773
# Batch 400: Loss = 0.0772
# Batch 500: Loss = 0.0771
# Batch 600: Loss = 0.0771
# Batch 700: Loss = 0.0770
# Batch 800: Loss = 0.0769
# Batch 900: Loss = 0.0768
# Epoch 33: Loss = 0.7718
# Batch 0: Loss = 0.0768
# Batch 100: Loss = 0.0767
# Batch 200: Loss = 0.0766
# Batch 300: Loss = 0.0765
# Batch 400: Loss = 0.0765
# Batch 500: Loss = 0.0764
# Batch 600: Loss = 0.0763
# Batch 700: Loss = 0.0763
# Batch 800: Loss = 0.0762
# Batch 900: Loss = 0.0761
# Epoch 34: Loss = 0.7644
# Batch 0: Loss = 0.0760
# Batch 100: Loss = 0.0760
# Batch 200: Loss = 0.0759
# Batch 300: Loss = 0.0758
# Batch 400: Loss = 0.0758
# Batch 500: Loss = 0.0757
# Batch 600: Loss = 0.0756
# Batch 700: Loss = 0.0756
# Batch 800: Loss = 0.0755
# Batch 900: Loss = 0.0754
# Epoch 35: Loss = 0.7573
# Batch 0: Loss = 0.0754
# Batch 100: Loss = 0.0753
# Batch 200: Loss = 0.0752
# Batch 300: Loss = 0.0751
# Batch 400: Loss = 0.0751
# Batch 500: Loss = 0.0750
# Batch 600: Loss = 0.0749
# Batch 700: Loss = 0.0749
# Batch 800: Loss = 0.0748
# Batch 900: Loss = 0.0747
# Epoch 36: Loss = 0.7505
# Batch 0: Loss = 0.0747
# Batch 100: Loss = 0.0746
# Batch 200: Loss = 0.0746
# Batch 300: Loss = 0.0745
# Batch 400: Loss = 0.0744
# Batch 500: Loss = 0.0744
# Batch 600: Loss = 0.0743
# Batch 700: Loss = 0.0742
# Batch 800: Loss = 0.0742
# Batch 900: Loss = 0.0741
# Epoch 37: Loss = 0.7439
# Batch 0: Loss = 0.0740
# Batch 100: Loss = 0.0740
# Batch 200: Loss = 0.0739
# Batch 300: Loss = 0.0738
# Batch 400: Loss = 0.0738
# Batch 500: Loss = 0.0737
# Batch 600: Loss = 0.0737
# Batch 700: Loss = 0.0736
# Batch 800: Loss = 0.0735
# Batch 900: Loss = 0.0735
# Epoch 38: Loss = 0.7375
# Batch 0: Loss = 0.0734
# Batch 100: Loss = 0.0734
# Batch 200: Loss = 0.0733
# Batch 300: Loss = 0.0732
# Batch 400: Loss = 0.0732
# Batch 500: Loss = 0.0731
# Batch 600: Loss = 0.0730
# Batch 700: Loss = 0.0730
# Batch 800: Loss = 0.0729
# Batch 900: Loss = 0.0729
# Epoch 39: Loss = 0.7314
# Batch 0: Loss = 0.0728
# Batch 100: Loss = 0.0727
# Batch 200: Loss = 0.0727
# Batch 300: Loss = 0.0726
# Batch 400: Loss = 0.0726
# Batch 500: Loss = 0.0725
# Batch 600: Loss = 0.0725
# Batch 700: Loss = 0.0724
# Batch 800: Loss = 0.0723
# Batch 900: Loss = 0.0723
# Epoch 40: Loss = 0.7254
# Batch 0: Loss = 0.0722
# Batch 100: Loss = 0.0722
# Batch 200: Loss = 0.0721
# Batch 300: Loss = 0.0720
# Batch 400: Loss = 0.0720
# Batch 500: Loss = 0.0719
# Batch 600: Loss = 0.0719
# Batch 700: Loss = 0.0718
# Batch 800: Loss = 0.0718
# Batch 900: Loss = 0.0717
# Epoch 41: Loss = 0.7196
# Batch 0: Loss = 0.0717
# Batch 100: Loss = 0.0716
# Batch 200: Loss = 0.0715
# Batch 300: Loss = 0.0715
# Batch 400: Loss = 0.0714
# Batch 500: Loss = 0.0714
# Batch 600: Loss = 0.0713
# Batch 700: Loss = 0.0713
# Batch 800: Loss = 0.0712
# Batch 900: Loss = 0.0712
# Epoch 42: Loss = 0.7140
# Batch 0: Loss = 0.0711
# Batch 100: Loss = 0.0710
# Batch 200: Loss = 0.0710
# Batch 300: Loss = 0.0709
# Batch 400: Loss = 0.0709
# Batch 500: Loss = 0.0708
# Batch 600: Loss = 0.0708
# Batch 700: Loss = 0.0707
# Batch 800: Loss = 0.0707
# Batch 900: Loss = 0.0706
# Epoch 43: Loss = 0.7086
# Batch 0: Loss = 0.0706
# Batch 100: Loss = 0.0705
# Batch 200: Loss = 0.0705
# Batch 300: Loss = 0.0704
# Batch 400: Loss = 0.0704
# Batch 500: Loss = 0.0703
# Batch 600: Loss = 0.0703
# Batch 700: Loss = 0.0702
# Batch 800: Loss = 0.0702
# Batch 900: Loss = 0.0701
# Epoch 44: Loss = 0.7033
# Batch 0: Loss = 0.0701
# Batch 100: Loss = 0.0700
# Batch 200: Loss = 0.0699
# Batch 300: Loss = 0.0699
# Batch 400: Loss = 0.0698
# Batch 500: Loss = 0.0698
# Batch 600: Loss = 0.0697
# Batch 700: Loss = 0.0697
# Batch 800: Loss = 0.0696
# Batch 900: Loss = 0.0696
# Epoch 45: Loss = 0.6982
# Batch 0: Loss = 0.0695
# Batch 100: Loss = 0.0695
# Batch 200: Loss = 0.0694
# Batch 300: Loss = 0.0694
# Batch 400: Loss = 0.0693
# Batch 500: Loss = 0.0693
# Batch 600: Loss = 0.0693
# Batch 700: Loss = 0.0692
# Batch 800: Loss = 0.0692
# Batch 900: Loss = 0.0691
# Epoch 46: Loss = 0.6932
# Batch 0: Loss = 0.0691
# Batch 100: Loss = 0.0690
# Batch 200: Loss = 0.0690
# Batch 300: Loss = 0.0689
# Batch 400: Loss = 0.0689
# Batch 500: Loss = 0.0688
# Batch 600: Loss = 0.0688
# Batch 700: Loss = 0.0687
# Batch 800: Loss = 0.0687
# Batch 900: Loss = 0.0686
# Epoch 47: Loss = 0.6884
# Batch 0: Loss = 0.0686
# Batch 100: Loss = 0.0685
# Batch 200: Loss = 0.0685
# Batch 300: Loss = 0.0684
# Batch 400: Loss = 0.0684
# Batch 500: Loss = 0.0683
# Batch 600: Loss = 0.0683
# Batch 700: Loss = 0.0683
# Batch 800: Loss = 0.0682
# Batch 900: Loss = 0.0682
# Epoch 48: Loss = 0.6837
# Batch 0: Loss = 0.0681
# Batch 100: Loss = 0.0681
# Batch 200: Loss = 0.0680
# Batch 300: Loss = 0.0680
# Batch 400: Loss = 0.0679
# Batch 500: Loss = 0.0679
# Batch 600: Loss = 0.0678
# Batch 700: Loss = 0.0678
# Batch 800: Loss = 0.0678
# Batch 900: Loss = 0.0677
# Epoch 49: Loss = 0.6791
# Batch 0: Loss = 0.0677
# Batch 100: Loss = 0.0676
# Batch 200: Loss = 0.0676
# Batch 300: Loss = 0.0675
# Batch 400: Loss = 0.0675
# Batch 500: Loss = 0.0674
# Batch 600: Loss = 0.0674
# Batch 700: Loss = 0.0674
# Batch 800: Loss = 0.0673
# Batch 900: Loss = 0.0673
# Epoch 50: Loss = 0.6746
# Batch 0: Loss = 0.0672
# Batch 100: Loss = 0.0672
# Batch 200: Loss = 0.0671
# Batch 300: Loss = 0.0671
# Batch 400: Loss = 0.0670
# Batch 500: Loss = 0.0670
# Batch 600: Loss = 0.0670
# Batch 700: Loss = 0.0669
# Batch 800: Loss = 0.0669
# Batch 900: Loss = 0.0668
# Epoch 51: Loss = 0.6703
# Batch 0: Loss = 0.0668
# Batch 100: Loss = 0.0667
# Batch 200: Loss = 0.0667
# Batch 300: Loss = 0.0667
# Batch 400: Loss = 0.0666
# Batch 500: Loss = 0.0666
# Batch 600: Loss = 0.0665
# Batch 700: Loss = 0.0665
# Batch 800: Loss = 0.0665
# Batch 900: Loss = 0.0664
# Epoch 52: Loss = 0.6660
# Batch 0: Loss = 0.0664
# Batch 100: Loss = 0.0663
# Batch 200: Loss = 0.0663
# Batch 300: Loss = 0.0662
# Batch 400: Loss = 0.0662
# Batch 500: Loss = 0.0662
# Batch 600: Loss = 0.0661
# Batch 700: Loss = 0.0661
# Batch 800: Loss = 0.0660
# Batch 900: Loss = 0.0660
# Epoch 53: Loss = 0.6619
# Batch 0: Loss = 0.0660
# Batch 100: Loss = 0.0659
# Batch 200: Loss = 0.0659
# Batch 300: Loss = 0.0658
# Batch 400: Loss = 0.0658
# Batch 500: Loss = 0.0658
# Batch 600: Loss = 0.0657
# Batch 700: Loss = 0.0657
# Batch 800: Loss = 0.0656
# Batch 900: Loss = 0.0656
# Epoch 54: Loss = 0.6578
# Batch 0: Loss = 0.0656
# Batch 100: Loss = 0.0655
# Batch 200: Loss = 0.0655
# Batch 300: Loss = 0.0654
# Batch 400: Loss = 0.0654
# Batch 500: Loss = 0.0654
# Batch 600: Loss = 0.0653
# Batch 700: Loss = 0.0653
# Batch 800: Loss = 0.0653
# Batch 900: Loss = 0.0652
# Epoch 55: Loss = 0.6539
# Batch 0: Loss = 0.0652
# Batch 100: Loss = 0.0651
# Batch 200: Loss = 0.0651
# Batch 300: Loss = 0.0651
# Batch 400: Loss = 0.0650
# Batch 500: Loss = 0.0650
# Batch 600: Loss = 0.0649
# Batch 700: Loss = 0.0649
# Batch 800: Loss = 0.0649
# Batch 900: Loss = 0.0648
# Epoch 56: Loss = 0.6500
# Batch 0: Loss = 0.0648
# Batch 100: Loss = 0.0648
# Batch 200: Loss = 0.0647
# Batch 300: Loss = 0.0647
# Batch 400: Loss = 0.0646
# Batch 500: Loss = 0.0646
# Batch 600: Loss = 0.0646
# Batch 700: Loss = 0.0645
# Batch 800: Loss = 0.0645
# Batch 900: Loss = 0.0645
# Epoch 57: Loss = 0.6462
# Batch 0: Loss = 0.0644
# Batch 100: Loss = 0.0644
# Batch 200: Loss = 0.0643
# Batch 300: Loss = 0.0643
# Batch 400: Loss = 0.0643
# Batch 500: Loss = 0.0642
# Batch 600: Loss = 0.0642
# Batch 700: Loss = 0.0642
# Batch 800: Loss = 0.0641
# Batch 900: Loss = 0.0641
# Epoch 58: Loss = 0.6426
# Batch 0: Loss = 0.0641
# Batch 100: Loss = 0.0640
# Batch 200: Loss = 0.0640
# Batch 300: Loss = 0.0639
# Batch 400: Loss = 0.0639
# Batch 500: Loss = 0.0639
# Batch 600: Loss = 0.0638
# Batch 700: Loss = 0.0638
# Batch 800: Loss = 0.0638
# Batch 900: Loss = 0.0637
# Epoch 59: Loss = 0.6390
# Batch 0: Loss = 0.0637
# Batch 100: Loss = 0.0637
# Batch 200: Loss = 0.0636
# Batch 300: Loss = 0.0636
# Batch 400: Loss = 0.0636
# Batch 500: Loss = 0.0635
# Batch 600: Loss = 0.0635
# Batch 700: Loss = 0.0635
# Batch 800: Loss = 0.0634
# Batch 900: Loss = 0.0634
# Epoch 60: Loss = 0.6354
# Batch 0: Loss = 0.0634
# Batch 100: Loss = 0.0633
# Batch 200: Loss = 0.0633
# Batch 300: Loss = 0.0632
# Batch 400: Loss = 0.0632
# Batch 500: Loss = 0.0632
# Batch 600: Loss = 0.0631
# Batch 700: Loss = 0.0631
# Batch 800: Loss = 0.0631
# Batch 900: Loss = 0.0630
# Epoch 61: Loss = 0.6320
# Batch 0: Loss = 0.0630
# Batch 100: Loss = 0.0630
# Batch 200: Loss = 0.0629
# Batch 300: Loss = 0.0629
# Batch 400: Loss = 0.0629
# Batch 500: Loss = 0.0628
# Batch 600: Loss = 0.0628
# Batch 700: Loss = 0.0628
# Batch 800: Loss = 0.0627
# Batch 900: Loss = 0.0627
# Epoch 62: Loss = 0.6286
# Batch 0: Loss = 0.0627
# Batch 100: Loss = 0.0626
# Batch 200: Loss = 0.0626
# Batch 300: Loss = 0.0626
# Batch 400: Loss = 0.0625
# Batch 500: Loss = 0.0625
# Batch 600: Loss = 0.0625
# Batch 700: Loss = 0.0624
# Batch 800: Loss = 0.0624
# Batch 900: Loss = 0.0624
# Epoch 63: Loss = 0.6253
# Batch 0: Loss = 0.0623
# Batch 100: Loss = 0.0623
# Batch 200: Loss = 0.0623
# Batch 300: Loss = 0.0623
# Batch 400: Loss = 0.0622
# Batch 500: Loss = 0.0622
# Batch 600: Loss = 0.0622
# Batch 700: Loss = 0.0621
# Batch 800: Loss = 0.0621
# Batch 900: Loss = 0.0621
# Epoch 64: Loss = 0.6220
# Batch 0: Loss = 0.0620
# Batch 100: Loss = 0.0620
# Batch 200: Loss = 0.0620
# Batch 300: Loss = 0.0619
# Batch 400: Loss = 0.0619
# Batch 500: Loss = 0.0619
# Batch 600: Loss = 0.0618
# Batch 700: Loss = 0.0618
# Batch 800: Loss = 0.0618
# Batch 900: Loss = 0.0617
# Epoch 65: Loss = 0.6188
# Batch 0: Loss = 0.0617
# Batch 100: Loss = 0.0617
# Batch 200: Loss = 0.0617
# Batch 300: Loss = 0.0616
# Batch 400: Loss = 0.0616
# Batch 500: Loss = 0.0616
# Batch 600: Loss = 0.0615
# Batch 700: Loss = 0.0615
# Batch 800: Loss = 0.0615
# Batch 900: Loss = 0.0614
# Epoch 66: Loss = 0.6157
# Batch 0: Loss = 0.0614
# Batch 100: Loss = 0.0614
# Batch 200: Loss = 0.0613
# Batch 300: Loss = 0.0613
# Batch 400: Loss = 0.0613
# Batch 500: Loss = 0.0613
# Batch 600: Loss = 0.0612
# Batch 700: Loss = 0.0612
# Batch 800: Loss = 0.0612
# Batch 900: Loss = 0.0611
# Epoch 67: Loss = 0.6127
# Batch 0: Loss = 0.0611
# Batch 100: Loss = 0.0611
# Batch 200: Loss = 0.0610
# Batch 300: Loss = 0.0610
# Batch 400: Loss = 0.0610
# Batch 500: Loss = 0.0610
# Batch 600: Loss = 0.0609
# Batch 700: Loss = 0.0609
# Batch 800: Loss = 0.0609
# Batch 900: Loss = 0.0608
# Epoch 68: Loss = 0.6097
# Batch 0: Loss = 0.0608
# Batch 100: Loss = 0.0608
# Batch 200: Loss = 0.0607
# Batch 300: Loss = 0.0607
# Batch 400: Loss = 0.0607
# Batch 500: Loss = 0.0607
# Batch 600: Loss = 0.0606
# Batch 700: Loss = 0.0606
# Batch 800: Loss = 0.0606
# Batch 900: Loss = 0.0605
# Epoch 69: Loss = 0.6067
# Batch 0: Loss = 0.0605
# Batch 100: Loss = 0.0605
# Batch 200: Loss = 0.0605
# Batch 300: Loss = 0.0604
# Batch 400: Loss = 0.0604
# Batch 500: Loss = 0.0604
# Batch 600: Loss = 0.0603
# Batch 700: Loss = 0.0603
# Batch 800: Loss = 0.0603
# Batch 900: Loss = 0.0603
# Epoch 70: Loss = 0.6038
# Batch 0: Loss = 0.0602
# Batch 100: Loss = 0.0602
# Batch 200: Loss = 0.0602
# Batch 300: Loss = 0.0601
# Batch 400: Loss = 0.0601
# Batch 500: Loss = 0.0601
# Batch 600: Loss = 0.0601
# Batch 700: Loss = 0.0600
# Batch 800: Loss = 0.0600
# Batch 900: Loss = 0.0600
# Epoch 71: Loss = 0.6010
# Batch 0: Loss = 0.0599
# Batch 100: Loss = 0.0599
# Batch 200: Loss = 0.0599
# Batch 300: Loss = 0.0599
# Batch 400: Loss = 0.0598
# Batch 500: Loss = 0.0598
# Batch 600: Loss = 0.0598
# Batch 700: Loss = 0.0598
# Batch 800: Loss = 0.0597
# Batch 900: Loss = 0.0597
# Epoch 72: Loss = 0.5982
# Batch 0: Loss = 0.0597
# Batch 100: Loss = 0.0596
# Batch 200: Loss = 0.0596
# Batch 300: Loss = 0.0596
# Batch 400: Loss = 0.0596
# Batch 500: Loss = 0.0595
# Batch 600: Loss = 0.0595
# Batch 700: Loss = 0.0595
# Batch 800: Loss = 0.0595
# Batch 900: Loss = 0.0594
# Epoch 73: Loss = 0.5955
# Batch 0: Loss = 0.0594
# Batch 100: Loss = 0.0594
# Batch 200: Loss = 0.0593
# Batch 300: Loss = 0.0593
# Batch 400: Loss = 0.0593
# Batch 500: Loss = 0.0593
# Batch 600: Loss = 0.0592
# Batch 700: Loss = 0.0592
# Batch 800: Loss = 0.0592
# Batch 900: Loss = 0.0592
# Epoch 74: Loss = 0.5928
# Batch 0: Loss = 0.0591
# Batch 100: Loss = 0.0591
# Batch 200: Loss = 0.0591
# Batch 300: Loss = 0.0591
# Batch 400: Loss = 0.0590
# Batch 500: Loss = 0.0590
# Batch 600: Loss = 0.0590
# Batch 700: Loss = 0.0590
# Batch 800: Loss = 0.0589
# Batch 900: Loss = 0.0589
# Epoch 75: Loss = 0.5902
# Batch 0: Loss = 0.0589
# Batch 100: Loss = 0.0588
# Batch 200: Loss = 0.0588
# Batch 300: Loss = 0.0588
# Batch 400: Loss = 0.0588
# Batch 500: Loss = 0.0587
# Batch 600: Loss = 0.0587
# Batch 700: Loss = 0.0587
# Batch 800: Loss = 0.0587
# Batch 900: Loss = 0.0586
# Epoch 76: Loss = 0.5876
# Batch 0: Loss = 0.0586
# Batch 100: Loss = 0.0586
# Batch 200: Loss = 0.0586
# Batch 300: Loss = 0.0585
# Batch 400: Loss = 0.0585
# Batch 500: Loss = 0.0585
# Batch 600: Loss = 0.0585
# Batch 700: Loss = 0.0584
# Batch 800: Loss = 0.0584
# Batch 900: Loss = 0.0584
# Epoch 77: Loss = 0.5850
# Batch 0: Loss = 0.0584
# Batch 100: Loss = 0.0583
# Batch 200: Loss = 0.0583
# Batch 300: Loss = 0.0583
# Batch 400: Loss = 0.0583
# Batch 500: Loss = 0.0582
# Batch 600: Loss = 0.0582
# Batch 700: Loss = 0.0582
# Batch 800: Loss = 0.0582
# Batch 900: Loss = 0.0581
# Epoch 78: Loss = 0.5825
# Batch 0: Loss = 0.0581
# Batch 100: Loss = 0.0581
# Batch 200: Loss = 0.0581
# Batch 300: Loss = 0.0580
# Batch 400: Loss = 0.0580
# Batch 500: Loss = 0.0580
# Batch 600: Loss = 0.0580
# Batch 700: Loss = 0.0579
# Batch 800: Loss = 0.0579
# Batch 900: Loss = 0.0579
# Epoch 79: Loss = 0.5800
# Batch 0: Loss = 0.0579
# Batch 100: Loss = 0.0578
# Batch 200: Loss = 0.0578
# Batch 300: Loss = 0.0578
# Batch 400: Loss = 0.0578
# Batch 500: Loss = 0.0577
# Batch 600: Loss = 0.0577
# Batch 700: Loss = 0.0577
# Batch 800: Loss = 0.0577
# Batch 900: Loss = 0.0577
# Epoch 80: Loss = 0.5776
# Batch 0: Loss = 0.0576
# Batch 100: Loss = 0.0576
# Batch 200: Loss = 0.0576
# Batch 300: Loss = 0.0576
# Batch 400: Loss = 0.0575
# Batch 500: Loss = 0.0575
# Batch 600: Loss = 0.0575
# Batch 700: Loss = 0.0575
# Batch 800: Loss = 0.0574
# Batch 900: Loss = 0.0574
# Epoch 81: Loss = 0.5752
# Batch 0: Loss = 0.0574
# Batch 100: Loss = 0.0574
# Batch 200: Loss = 0.0573
# Batch 300: Loss = 0.0573
# Batch 400: Loss = 0.0573
# Batch 500: Loss = 0.0573
# Batch 600: Loss = 0.0573
# Batch 700: Loss = 0.0572
# Batch 800: Loss = 0.0572
# Batch 900: Loss = 0.0572
# Epoch 82: Loss = 0.5729
# Batch 0: Loss = 0.0572
# Batch 100: Loss = 0.0571
# Batch 200: Loss = 0.0571
# Batch 300: Loss = 0.0571
# Batch 400: Loss = 0.0571
# Batch 500: Loss = 0.0570
# Batch 600: Loss = 0.0570
# Batch 700: Loss = 0.0570
# Batch 800: Loss = 0.0570
# Batch 900: Loss = 0.0570
# Epoch 83: Loss = 0.5706
# Batch 0: Loss = 0.0569
# Batch 100: Loss = 0.0569
# Batch 200: Loss = 0.0569
# Batch 300: Loss = 0.0569
# Batch 400: Loss = 0.0568
# Batch 500: Loss = 0.0568
# Batch 600: Loss = 0.0568
# Batch 700: Loss = 0.0568
# Batch 800: Loss = 0.0568
# Batch 900: Loss = 0.0567
# Epoch 84: Loss = 0.5683
# Batch 0: Loss = 0.0567
# Batch 100: Loss = 0.0567
# Batch 200: Loss = 0.0567
# Batch 300: Loss = 0.0566
# Batch 400: Loss = 0.0566
# Batch 500: Loss = 0.0566
# Batch 600: Loss = 0.0566
# Batch 700: Loss = 0.0566
# Batch 800: Loss = 0.0565
# Batch 900: Loss = 0.0565
# Epoch 85: Loss = 0.5661
# Batch 0: Loss = 0.0565
# Batch 100: Loss = 0.0565
# Batch 200: Loss = 0.0564
# Batch 300: Loss = 0.0564
# Batch 400: Loss = 0.0564
# Batch 500: Loss = 0.0564
# Batch 600: Loss = 0.0564
# Batch 700: Loss = 0.0563
# Batch 800: Loss = 0.0563
# Batch 900: Loss = 0.0563
# Epoch 86: Loss = 0.5639
# Batch 0: Loss = 0.0563
# Batch 100: Loss = 0.0562
# Batch 200: Loss = 0.0562
# Batch 300: Loss = 0.0562
# Batch 400: Loss = 0.0562
# Batch 500: Loss = 0.0562
# Batch 600: Loss = 0.0561
# Batch 700: Loss = 0.0561
# Batch 800: Loss = 0.0561
# Batch 900: Loss = 0.0561
# Epoch 87: Loss = 0.5617
# Batch 0: Loss = 0.0560
# Batch 100: Loss = 0.0560
# Batch 200: Loss = 0.0560
# Batch 300: Loss = 0.0560
# Batch 400: Loss = 0.0560
# Batch 500: Loss = 0.0559
# Batch 600: Loss = 0.0559
# Batch 700: Loss = 0.0559
# Batch 800: Loss = 0.0559
# Batch 900: Loss = 0.0559
# Epoch 88: Loss = 0.5595
# Batch 0: Loss = 0.0558
# Batch 100: Loss = 0.0558
# Batch 200: Loss = 0.0558
# Batch 300: Loss = 0.0558
# Batch 400: Loss = 0.0558
# Batch 500: Loss = 0.0557
# Batch 600: Loss = 0.0557
# Batch 700: Loss = 0.0557
# Batch 800: Loss = 0.0557
# Batch 900: Loss = 0.0556
# Epoch 89: Loss = 0.5574
# Batch 0: Loss = 0.0556
# Batch 100: Loss = 0.0556
# Batch 200: Loss = 0.0556
# Batch 300: Loss = 0.0556
# Batch 400: Loss = 0.0555
# Batch 500: Loss = 0.0555
# Batch 600: Loss = 0.0555
# Batch 700: Loss = 0.0555
# Batch 800: Loss = 0.0555
# Batch 900: Loss = 0.0554
# Epoch 90: Loss = 0.5553
# Batch 0: Loss = 0.0554
# Batch 100: Loss = 0.0554
# Batch 200: Loss = 0.0554
# Batch 300: Loss = 0.0554
# Batch 400: Loss = 0.0553
# Batch 500: Loss = 0.0553
# Batch 600: Loss = 0.0553
# Batch 700: Loss = 0.0553
# Batch 800: Loss = 0.0553
# Batch 900: Loss = 0.0552
# Epoch 91: Loss = 0.5533
# Batch 0: Loss = 0.0552
# Batch 100: Loss = 0.0552
# Batch 200: Loss = 0.0552
# Batch 300: Loss = 0.0552
# Batch 400: Loss = 0.0551
# Batch 500: Loss = 0.0551
# Batch 600: Loss = 0.0551
# Batch 700: Loss = 0.0551
# Batch 800: Loss = 0.0551
# Batch 900: Loss = 0.0550
# Epoch 92: Loss = 0.5513
# Batch 0: Loss = 0.0550
# Batch 100: Loss = 0.0550
# Batch 200: Loss = 0.0550
# Batch 300: Loss = 0.0550
# Batch 400: Loss = 0.0549
# Batch 500: Loss = 0.0549
# Batch 600: Loss = 0.0549
# Batch 700: Loss = 0.0549
# Batch 800: Loss = 0.0549
# Batch 900: Loss = 0.0548
# Epoch 93: Loss = 0.5493
# Batch 0: Loss = 0.0548
# Batch 100: Loss = 0.0548
# Batch 200: Loss = 0.0548
# Batch 300: Loss = 0.0548
# Batch 400: Loss = 0.0547
# Batch 500: Loss = 0.0547
# Batch 600: Loss = 0.0547
# Batch 700: Loss = 0.0547
# Batch 800: Loss = 0.0547
# Batch 900: Loss = 0.0546
# Epoch 94: Loss = 0.5473
# Batch 0: Loss = 0.0546
# Batch 100: Loss = 0.0546
# Batch 200: Loss = 0.0546
# Batch 300: Loss = 0.0546
# Batch 400: Loss = 0.0545
# Batch 500: Loss = 0.0545
# Batch 600: Loss = 0.0545
# Batch 700: Loss = 0.0545
# Batch 800: Loss = 0.0545
# Batch 900: Loss = 0.0545
# Epoch 95: Loss = 0.5454
# Batch 0: Loss = 0.0544
# Batch 100: Loss = 0.0544
# Batch 200: Loss = 0.0544
# Batch 300: Loss = 0.0544
# Batch 400: Loss = 0.0544
# Batch 500: Loss = 0.0543
# Batch 600: Loss = 0.0543
# Batch 700: Loss = 0.0543
# Batch 800: Loss = 0.0543
# Batch 900: Loss = 0.0543
# Epoch 96: Loss = 0.5435
# Batch 0: Loss = 0.0542
# Batch 100: Loss = 0.0542
# Batch 200: Loss = 0.0542
# Batch 300: Loss = 0.0542
# Batch 400: Loss = 0.0542
# Batch 500: Loss = 0.0541
# Batch 600: Loss = 0.0541
# Batch 700: Loss = 0.0541
# Batch 800: Loss = 0.0541
# Batch 900: Loss = 0.0541
# Epoch 97: Loss = 0.5416
# Batch 0: Loss = 0.0541
# Batch 100: Loss = 0.0540
# Batch 200: Loss = 0.0540
# Batch 300: Loss = 0.0540
# Batch 400: Loss = 0.0540
# Batch 500: Loss = 0.0540
# Batch 600: Loss = 0.0539
# Batch 700: Loss = 0.0539
# Batch 800: Loss = 0.0539
# Batch 900: Loss = 0.0539
# Epoch 98: Loss = 0.5397
# Batch 0: Loss = 0.0539
# Batch 100: Loss = 0.0539
# Batch 200: Loss = 0.0538
# Batch 300: Loss = 0.0538
# Batch 400: Loss = 0.0538
# Batch 500: Loss = 0.0538
# Batch 600: Loss = 0.0538
# Batch 700: Loss = 0.0537
# Batch 800: Loss = 0.0537
# Batch 900: Loss = 0.0537
# Epoch 99: Loss = 0.5379
# Batch 0: Loss = 0.0537
# Batch 100: Loss = 0.0537
# Batch 200: Loss = 0.0537
# Batch 300: Loss = 0.0536
# Batch 400: Loss = 0.0536
# Batch 500: Loss = 0.0536
# Batch 600: Loss = 0.0536
# Batch 700: Loss = 0.0536
# Batch 800: Loss = 0.0535
# Batch 900: Loss = 0.0535
# Epoch 100: Loss = 0.5361

# %% [markdown]
# As we can see, the loss is much lower now with the momentum term.
#
# Using a scheduler to change the lr along with training

# %%
from torch.optim.lr_scheduler import StepLR

num_iterations = 100
learning_rate = 0.5 # higher than before as we will reduce this over steps

# torch.optim.SGD
w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)

optimizer = SGD([w, b], lr=learning_rate, momentum=0.9)
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

for step in range(num_iterations):

    # shuffle X, Y
    perm = torch.randperm(m)
    X_shuffled, Y_shuffled = X[:, perm], Y[:, perm]

    epoch_loss = 0.0

    # use mini-batches
    for batch in range(0, m, 100):

        X_batch, Y_batch = X_shuffled[:, batch:batch+100], Y_shuffled[:, batch:batch+100]

        z = w.T @ X_shuffled + b
        a = sigmoid(z)

        loss = binary_cross_entropy_loss(a, Y_shuffled)
        epoch_loss += loss

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        print(f"Batch {batch}: Loss = {loss.item():.4f}")

    scheduler.step()

    print(f"Epoch {step+1}: Loss = {epoch_loss.item():.4f}")
# Out:
# Batch 0: Loss = 0.6931
# Batch 100: Loss = 0.6198
# Batch 200: Loss = 0.5115
# Batch 300: Loss = 0.4078
# Batch 400: Loss = 0.3265
# Batch 500: Loss = 0.2677
# Batch 600: Loss = 0.2257
# Batch 700: Loss = 0.1954
# Batch 800: Loss = 0.1729
# Batch 900: Loss = 0.1559
# Epoch 1: Loss = 3.5765
# Batch 0: Loss = 0.1427
# Batch 100: Loss = 0.1323
# Batch 200: Loss = 0.1238
# Batch 300: Loss = 0.1168
# Batch 400: Loss = 0.1110
# Batch 500: Loss = 0.1061
# Batch 600: Loss = 0.1020
# Batch 700: Loss = 0.0984
# Batch 800: Loss = 0.0952
# Batch 900: Loss = 0.0925
# Epoch 2: Loss = 1.1209
# Batch 0: Loss = 0.0901
# Batch 100: Loss = 0.0880
# Batch 200: Loss = 0.0861
# Batch 300: Loss = 0.0844
# Batch 400: Loss = 0.0829
# Batch 500: Loss = 0.0815
# Batch 600: Loss = 0.0803
# Batch 700: Loss = 0.0791
# Batch 800: Loss = 0.0781
# Batch 900: Loss = 0.0772
# Epoch 3: Loss = 0.8276
# Batch 0: Loss = 0.0763
# Batch 100: Loss = 0.0755
# Batch 200: Loss = 0.0748
# Batch 300: Loss = 0.0741
# Batch 400: Loss = 0.0735
# Batch 500: Loss = 0.0729
# Batch 600: Loss = 0.0724
# Batch 700: Loss = 0.0718
# Batch 800: Loss = 0.0714
# Batch 900: Loss = 0.0709
# Epoch 4: Loss = 0.7336
# Batch 0: Loss = 0.0705
# Batch 100: Loss = 0.0700
# Batch 200: Loss = 0.0696
# Batch 300: Loss = 0.0693
# Batch 400: Loss = 0.0689
# Batch 500: Loss = 0.0686
# Batch 600: Loss = 0.0682
# Batch 700: Loss = 0.0679
# Batch 800: Loss = 0.0676
# Batch 900: Loss = 0.0673
# Epoch 5: Loss = 0.6880
# Batch 0: Loss = 0.0670
# Batch 100: Loss = 0.0668
# Batch 200: Loss = 0.0665
# Batch 300: Loss = 0.0662
# Batch 400: Loss = 0.0660
# Batch 500: Loss = 0.0658
# Batch 600: Loss = 0.0655
# Batch 700: Loss = 0.0653
# Batch 800: Loss = 0.0651
# Batch 900: Loss = 0.0648
# Epoch 6: Loss = 0.6590
# Batch 0: Loss = 0.0646
# Batch 100: Loss = 0.0644
# Batch 200: Loss = 0.0642
# Batch 300: Loss = 0.0640
# Batch 400: Loss = 0.0638
# Batch 500: Loss = 0.0636
# Batch 600: Loss = 0.0634
# Batch 700: Loss = 0.0632
# Batch 800: Loss = 0.0630
# Batch 900: Loss = 0.0629
# Epoch 7: Loss = 0.6372
# Batch 0: Loss = 0.0627
# Batch 100: Loss = 0.0625
# Batch 200: Loss = 0.0623
# Batch 300: Loss = 0.0621
# Batch 400: Loss = 0.0620
# Batch 500: Loss = 0.0618
# Batch 600: Loss = 0.0616
# Batch 700: Loss = 0.0615
# Batch 800: Loss = 0.0613
# Batch 900: Loss = 0.0611
# Epoch 8: Loss = 0.6190
# Batch 0: Loss = 0.0610
# Batch 100: Loss = 0.0608
# Batch 200: Loss = 0.0607
# Batch 300: Loss = 0.0605
# Batch 400: Loss = 0.0604
# Batch 500: Loss = 0.0602
# Batch 600: Loss = 0.0601
# Batch 700: Loss = 0.0599
# Batch 800: Loss = 0.0598
# Batch 900: Loss = 0.0596
# Epoch 9: Loss = 0.6031
# Batch 0: Loss = 0.0595
# Batch 100: Loss = 0.0594
# Batch 200: Loss = 0.0592
# Batch 300: Loss = 0.0591
# Batch 400: Loss = 0.0589
# Batch 500: Loss = 0.0588
# Batch 600: Loss = 0.0587
# Batch 700: Loss = 0.0585
# Batch 800: Loss = 0.0584
# Batch 900: Loss = 0.0583
# Epoch 10: Loss = 0.5888
# Batch 0: Loss = 0.0582
# Batch 100: Loss = 0.0581
# Batch 200: Loss = 0.0580
# Batch 300: Loss = 0.0580
# Batch 400: Loss = 0.0579
# Batch 500: Loss = 0.0578
# Batch 600: Loss = 0.0578
# Batch 700: Loss = 0.0577
# Batch 800: Loss = 0.0577
# Batch 900: Loss = 0.0576
# Epoch 11: Loss = 0.5787
# Batch 0: Loss = 0.0575
# Batch 100: Loss = 0.0575
# Batch 200: Loss = 0.0574
# Batch 300: Loss = 0.0574
# Batch 400: Loss = 0.0573
# Batch 500: Loss = 0.0572
# Batch 600: Loss = 0.0572
# Batch 700: Loss = 0.0571
# Batch 800: Loss = 0.0571
# Batch 900: Loss = 0.0570
# Epoch 12: Loss = 0.5726
# Batch 0: Loss = 0.0569
# Batch 100: Loss = 0.0569
# Batch 200: Loss = 0.0568
# Batch 300: Loss = 0.0568
# Batch 400: Loss = 0.0567
# Batch 500: Loss = 0.0567
# Batch 600: Loss = 0.0566
# Batch 700: Loss = 0.0565
# Batch 800: Loss = 0.0565
# Batch 900: Loss = 0.0564
# Epoch 13: Loss = 0.5668
# Batch 0: Loss = 0.0564
# Batch 100: Loss = 0.0563
# Batch 200: Loss = 0.0563
# Batch 300: Loss = 0.0562
# Batch 400: Loss = 0.0562
# Batch 500: Loss = 0.0561
# Batch 600: Loss = 0.0560
# Batch 700: Loss = 0.0560
# Batch 800: Loss = 0.0559
# Batch 900: Loss = 0.0559
# Epoch 14: Loss = 0.5613
# Batch 0: Loss = 0.0558
# Batch 100: Loss = 0.0558
# Batch 200: Loss = 0.0557
# Batch 300: Loss = 0.0557
# Batch 400: Loss = 0.0556
# Batch 500: Loss = 0.0556
# Batch 600: Loss = 0.0555
# Batch 700: Loss = 0.0555
# Batch 800: Loss = 0.0554
# Batch 900: Loss = 0.0554
# Epoch 15: Loss = 0.5559
# Batch 0: Loss = 0.0553
# Batch 100: Loss = 0.0553
# Batch 200: Loss = 0.0552
# Batch 300: Loss = 0.0552
# Batch 400: Loss = 0.0551
# Batch 500: Loss = 0.0551
# Batch 600: Loss = 0.0550
# Batch 700: Loss = 0.0550
# Batch 800: Loss = 0.0549
# Batch 900: Loss = 0.0549
# Epoch 16: Loss = 0.5508
# Batch 0: Loss = 0.0548
# Batch 100: Loss = 0.0548
# Batch 200: Loss = 0.0547
# Batch 300: Loss = 0.0547
# Batch 400: Loss = 0.0546
# Batch 500: Loss = 0.0546
# Batch 600: Loss = 0.0545
# Batch 700: Loss = 0.0545
# Batch 800: Loss = 0.0544
# Batch 900: Loss = 0.0544
# Epoch 17: Loss = 0.5458
# Batch 0: Loss = 0.0543
# Batch 100: Loss = 0.0543
# Batch 200: Loss = 0.0542
# Batch 300: Loss = 0.0542
# Batch 400: Loss = 0.0541
# Batch 500: Loss = 0.0541
# Batch 600: Loss = 0.0540
# Batch 700: Loss = 0.0540
# Batch 800: Loss = 0.0539
# Batch 900: Loss = 0.0539
# Epoch 18: Loss = 0.5410
# Batch 0: Loss = 0.0538
# Batch 100: Loss = 0.0538
# Batch 200: Loss = 0.0538
# Batch 300: Loss = 0.0537
# Batch 400: Loss = 0.0537
# Batch 500: Loss = 0.0536
# Batch 600: Loss = 0.0536
# Batch 700: Loss = 0.0535
# Batch 800: Loss = 0.0535
# Batch 900: Loss = 0.0534
# Epoch 19: Loss = 0.5364
# Batch 0: Loss = 0.0534
# Batch 100: Loss = 0.0533
# Batch 200: Loss = 0.0533
# Batch 300: Loss = 0.0533
# Batch 400: Loss = 0.0532
# Batch 500: Loss = 0.0532
# Batch 600: Loss = 0.0531
# Batch 700: Loss = 0.0531
# Batch 800: Loss = 0.0530
# Batch 900: Loss = 0.0530
# Epoch 20: Loss = 0.5319
# Batch 0: Loss = 0.0530
# Batch 100: Loss = 0.0529
# Batch 200: Loss = 0.0529
# Batch 300: Loss = 0.0529
# Batch 400: Loss = 0.0529
# Batch 500: Loss = 0.0528
# Batch 600: Loss = 0.0528
# Batch 700: Loss = 0.0528
# Batch 800: Loss = 0.0528
# Batch 900: Loss = 0.0528
# Epoch 21: Loss = 0.5286
# Batch 0: Loss = 0.0527
# Batch 100: Loss = 0.0527
# Batch 200: Loss = 0.0527
# Batch 300: Loss = 0.0527
# Batch 400: Loss = 0.0527
# Batch 500: Loss = 0.0526
# Batch 600: Loss = 0.0526
# Batch 700: Loss = 0.0526
# Batch 800: Loss = 0.0526
# Batch 900: Loss = 0.0526
# Epoch 22: Loss = 0.5264
# Batch 0: Loss = 0.0525
# Batch 100: Loss = 0.0525
# Batch 200: Loss = 0.0525
# Batch 300: Loss = 0.0525
# Batch 400: Loss = 0.0524
# Batch 500: Loss = 0.0524
# Batch 600: Loss = 0.0524
# Batch 700: Loss = 0.0524
# Batch 800: Loss = 0.0524
# Batch 900: Loss = 0.0523
# Epoch 23: Loss = 0.5244
# Batch 0: Loss = 0.0523
# Batch 100: Loss = 0.0523
# Batch 200: Loss = 0.0523
# Batch 300: Loss = 0.0523
# Batch 400: Loss = 0.0522
# Batch 500: Loss = 0.0522
# Batch 600: Loss = 0.0522
# Batch 700: Loss = 0.0522
# Batch 800: Loss = 0.0522
# Batch 900: Loss = 0.0521
# Epoch 24: Loss = 0.5223
# Batch 0: Loss = 0.0521
# Batch 100: Loss = 0.0521
# Batch 200: Loss = 0.0521
# Batch 300: Loss = 0.0521
# Batch 400: Loss = 0.0520
# Batch 500: Loss = 0.0520
# Batch 600: Loss = 0.0520
# Batch 700: Loss = 0.0520
# Batch 800: Loss = 0.0520
# Batch 900: Loss = 0.0519
# Epoch 25: Loss = 0.5203
# Batch 0: Loss = 0.0519
# Batch 100: Loss = 0.0519
# Batch 200: Loss = 0.0519
# Batch 300: Loss = 0.0519
# Batch 400: Loss = 0.0518
# Batch 500: Loss = 0.0518
# Batch 600: Loss = 0.0518
# Batch 700: Loss = 0.0518
# Batch 800: Loss = 0.0518
# Batch 900: Loss = 0.0517
# Epoch 26: Loss = 0.5183
# Batch 0: Loss = 0.0517
# Batch 100: Loss = 0.0517
# Batch 200: Loss = 0.0517
# Batch 300: Loss = 0.0517
# Batch 400: Loss = 0.0516
# Batch 500: Loss = 0.0516
# Batch 600: Loss = 0.0516
# Batch 700: Loss = 0.0516
# Batch 800: Loss = 0.0516
# Batch 900: Loss = 0.0515
# Epoch 27: Loss = 0.5163
# Batch 0: Loss = 0.0515
# Batch 100: Loss = 0.0515
# Batch 200: Loss = 0.0515
# Batch 300: Loss = 0.0515
# Batch 400: Loss = 0.0515
# Batch 500: Loss = 0.0514
# Batch 600: Loss = 0.0514
# Batch 700: Loss = 0.0514
# Batch 800: Loss = 0.0514
# Batch 900: Loss = 0.0514
# Epoch 28: Loss = 0.5144
# Batch 0: Loss = 0.0513
# Batch 100: Loss = 0.0513
# Batch 200: Loss = 0.0513
# Batch 300: Loss = 0.0513
# Batch 400: Loss = 0.0513
# Batch 500: Loss = 0.0512
# Batch 600: Loss = 0.0512
# Batch 700: Loss = 0.0512
# Batch 800: Loss = 0.0512
# Batch 900: Loss = 0.0512
# Epoch 29: Loss = 0.5125
# Batch 0: Loss = 0.0511
# Batch 100: Loss = 0.0511
# Batch 200: Loss = 0.0511
# Batch 300: Loss = 0.0511
# Batch 400: Loss = 0.0511
# Batch 500: Loss = 0.0511
# Batch 600: Loss = 0.0510
# Batch 700: Loss = 0.0510
# Batch 800: Loss = 0.0510
# Batch 900: Loss = 0.0510
# Epoch 30: Loss = 0.5106
# Batch 0: Loss = 0.0510
# Batch 100: Loss = 0.0510
# Batch 200: Loss = 0.0509
# Batch 300: Loss = 0.0509
# Batch 400: Loss = 0.0509
# Batch 500: Loss = 0.0509
# Batch 600: Loss = 0.0509
# Batch 700: Loss = 0.0509
# Batch 800: Loss = 0.0509
# Batch 900: Loss = 0.0509
# Epoch 31: Loss = 0.5092
# Batch 0: Loss = 0.0509
# Batch 100: Loss = 0.0509
# Batch 200: Loss = 0.0509
# Batch 300: Loss = 0.0508
# Batch 400: Loss = 0.0508
# Batch 500: Loss = 0.0508
# Batch 600: Loss = 0.0508
# Batch 700: Loss = 0.0508
# Batch 800: Loss = 0.0508
# Batch 900: Loss = 0.0508
# Epoch 32: Loss = 0.5083
# Batch 0: Loss = 0.0508
# Batch 100: Loss = 0.0508
# Batch 200: Loss = 0.0508
# Batch 300: Loss = 0.0508
# Batch 400: Loss = 0.0507
# Batch 500: Loss = 0.0507
# Batch 600: Loss = 0.0507
# Batch 700: Loss = 0.0507
# Batch 800: Loss = 0.0507
# Batch 900: Loss = 0.0507
# Epoch 33: Loss = 0.5074
# Batch 0: Loss = 0.0507
# Batch 100: Loss = 0.0507
# Batch 200: Loss = 0.0507
# Batch 300: Loss = 0.0507
# Batch 400: Loss = 0.0507
# Batch 500: Loss = 0.0506
# Batch 600: Loss = 0.0506
# Batch 700: Loss = 0.0506
# Batch 800: Loss = 0.0506
# Batch 900: Loss = 0.0506
# Epoch 34: Loss = 0.5065
# Batch 0: Loss = 0.0506
# Batch 100: Loss = 0.0506
# Batch 200: Loss = 0.0506
# Batch 300: Loss = 0.0506
# Batch 400: Loss = 0.0506
# Batch 500: Loss = 0.0506
# Batch 600: Loss = 0.0505
# Batch 700: Loss = 0.0505
# Batch 800: Loss = 0.0505
# Batch 900: Loss = 0.0505
# Epoch 35: Loss = 0.5056
# Batch 0: Loss = 0.0505
# Batch 100: Loss = 0.0505
# Batch 200: Loss = 0.0505
# Batch 300: Loss = 0.0505
# Batch 400: Loss = 0.0505
# Batch 500: Loss = 0.0505
# Batch 600: Loss = 0.0505
# Batch 700: Loss = 0.0504
# Batch 800: Loss = 0.0504
# Batch 900: Loss = 0.0504
# Epoch 36: Loss = 0.5047
# Batch 0: Loss = 0.0504
# Batch 100: Loss = 0.0504
# Batch 200: Loss = 0.0504
# Batch 300: Loss = 0.0504
# Batch 400: Loss = 0.0504
# Batch 500: Loss = 0.0504
# Batch 600: Loss = 0.0504
# Batch 700: Loss = 0.0504
# Batch 800: Loss = 0.0504
# Batch 900: Loss = 0.0503
# Epoch 37: Loss = 0.5038
# Batch 0: Loss = 0.0503
# Batch 100: Loss = 0.0503
# Batch 200: Loss = 0.0503
# Batch 300: Loss = 0.0503
# Batch 400: Loss = 0.0503
# Batch 500: Loss = 0.0503
# Batch 600: Loss = 0.0503
# Batch 700: Loss = 0.0503
# Batch 800: Loss = 0.0503
# Batch 900: Loss = 0.0503
# Epoch 38: Loss = 0.5029
# Batch 0: Loss = 0.0502
# Batch 100: Loss = 0.0502
# Batch 200: Loss = 0.0502
# Batch 300: Loss = 0.0502
# Batch 400: Loss = 0.0502
# Batch 500: Loss = 0.0502
# Batch 600: Loss = 0.0502
# Batch 700: Loss = 0.0502
# Batch 800: Loss = 0.0502
# Batch 900: Loss = 0.0502
# Epoch 39: Loss = 0.5021
# Batch 0: Loss = 0.0502
# Batch 100: Loss = 0.0501
# Batch 200: Loss = 0.0501
# Batch 300: Loss = 0.0501
# Batch 400: Loss = 0.0501
# Batch 500: Loss = 0.0501
# Batch 600: Loss = 0.0501
# Batch 700: Loss = 0.0501
# Batch 800: Loss = 0.0501
# Batch 900: Loss = 0.0501
# Epoch 40: Loss = 0.5012
# Batch 0: Loss = 0.0501
# Batch 100: Loss = 0.0501
# Batch 200: Loss = 0.0501
# Batch 300: Loss = 0.0501
# Batch 400: Loss = 0.0501
# Batch 500: Loss = 0.0501
# Batch 600: Loss = 0.0500
# Batch 700: Loss = 0.0500
# Batch 800: Loss = 0.0500
# Batch 900: Loss = 0.0500
# Epoch 41: Loss = 0.5005
# Batch 0: Loss = 0.0500
# Batch 100: Loss = 0.0500
# Batch 200: Loss = 0.0500
# Batch 300: Loss = 0.0500
# Batch 400: Loss = 0.0500
# Batch 500: Loss = 0.0500
# Batch 600: Loss = 0.0500
# Batch 700: Loss = 0.0500
# Batch 800: Loss = 0.0500
# Batch 900: Loss = 0.0500
# Epoch 42: Loss = 0.5001
# Batch 0: Loss = 0.0500
# Batch 100: Loss = 0.0500
# Batch 200: Loss = 0.0500
# Batch 300: Loss = 0.0500
# Batch 400: Loss = 0.0500
# Batch 500: Loss = 0.0500
# Batch 600: Loss = 0.0500
# Batch 700: Loss = 0.0500
# Batch 800: Loss = 0.0500
# Batch 900: Loss = 0.0499
# Epoch 43: Loss = 0.4997
# Batch 0: Loss = 0.0499
# Batch 100: Loss = 0.0499
# Batch 200: Loss = 0.0499
# Batch 300: Loss = 0.0499
# Batch 400: Loss = 0.0499
# Batch 500: Loss = 0.0499
# Batch 600: Loss = 0.0499
# Batch 700: Loss = 0.0499
# Batch 800: Loss = 0.0499
# Batch 900: Loss = 0.0499
# Epoch 44: Loss = 0.4992
# Batch 0: Loss = 0.0499
# Batch 100: Loss = 0.0499
# Batch 200: Loss = 0.0499
# Batch 300: Loss = 0.0499
# Batch 400: Loss = 0.0499
# Batch 500: Loss = 0.0499
# Batch 600: Loss = 0.0499
# Batch 700: Loss = 0.0499
# Batch 800: Loss = 0.0499
# Batch 900: Loss = 0.0499
# Epoch 45: Loss = 0.4988
# Batch 0: Loss = 0.0499
# Batch 100: Loss = 0.0499
# Batch 200: Loss = 0.0499
# Batch 300: Loss = 0.0498
# Batch 400: Loss = 0.0498
# Batch 500: Loss = 0.0498
# Batch 600: Loss = 0.0498
# Batch 700: Loss = 0.0498
# Batch 800: Loss = 0.0498
# Batch 900: Loss = 0.0498
# Epoch 46: Loss = 0.4984
# Batch 0: Loss = 0.0498
# Batch 100: Loss = 0.0498
# Batch 200: Loss = 0.0498
# Batch 300: Loss = 0.0498
# Batch 400: Loss = 0.0498
# Batch 500: Loss = 0.0498
# Batch 600: Loss = 0.0498
# Batch 700: Loss = 0.0498
# Batch 800: Loss = 0.0498
# Batch 900: Loss = 0.0498
# Epoch 47: Loss = 0.4980
# Batch 0: Loss = 0.0498
# Batch 100: Loss = 0.0498
# Batch 200: Loss = 0.0498
# Batch 300: Loss = 0.0498
# Batch 400: Loss = 0.0498
# Batch 500: Loss = 0.0498
# Batch 600: Loss = 0.0498
# Batch 700: Loss = 0.0497
# Batch 800: Loss = 0.0497
# Batch 900: Loss = 0.0497
# Epoch 48: Loss = 0.4976
# Batch 0: Loss = 0.0497
# Batch 100: Loss = 0.0497
# Batch 200: Loss = 0.0497
# Batch 300: Loss = 0.0497
# Batch 400: Loss = 0.0497
# Batch 500: Loss = 0.0497
# Batch 600: Loss = 0.0497
# Batch 700: Loss = 0.0497
# Batch 800: Loss = 0.0497
# Batch 900: Loss = 0.0497
# Epoch 49: Loss = 0.4971
# Batch 0: Loss = 0.0497
# Batch 100: Loss = 0.0497
# Batch 200: Loss = 0.0497
# Batch 300: Loss = 0.0497
# Batch 400: Loss = 0.0497
# Batch 500: Loss = 0.0497
# Batch 600: Loss = 0.0497
# Batch 700: Loss = 0.0497
# Batch 800: Loss = 0.0497
# Batch 900: Loss = 0.0497
# Epoch 50: Loss = 0.4967
# Batch 0: Loss = 0.0497
# Batch 100: Loss = 0.0496
# Batch 200: Loss = 0.0496
# Batch 300: Loss = 0.0496
# Batch 400: Loss = 0.0496
# Batch 500: Loss = 0.0496
# Batch 600: Loss = 0.0496
# Batch 700: Loss = 0.0496
# Batch 800: Loss = 0.0496
# Batch 900: Loss = 0.0496
# Epoch 51: Loss = 0.4964
# Batch 0: Loss = 0.0496
# Batch 100: Loss = 0.0496
# Batch 200: Loss = 0.0496
# Batch 300: Loss = 0.0496
# Batch 400: Loss = 0.0496
# Batch 500: Loss = 0.0496
# Batch 600: Loss = 0.0496
# Batch 700: Loss = 0.0496
# Batch 800: Loss = 0.0496
# Batch 900: Loss = 0.0496
# Epoch 52: Loss = 0.4962
# Batch 0: Loss = 0.0496
# Batch 100: Loss = 0.0496
# Batch 200: Loss = 0.0496
# Batch 300: Loss = 0.0496
# Batch 400: Loss = 0.0496
# Batch 500: Loss = 0.0496
# Batch 600: Loss = 0.0496
# Batch 700: Loss = 0.0496
# Batch 800: Loss = 0.0496
# Batch 900: Loss = 0.0496
# Epoch 53: Loss = 0.4960
# Batch 0: Loss = 0.0496
# Batch 100: Loss = 0.0496
# Batch 200: Loss = 0.0496
# Batch 300: Loss = 0.0496
# Batch 400: Loss = 0.0496
# Batch 500: Loss = 0.0496
# Batch 600: Loss = 0.0496
# Batch 700: Loss = 0.0496
# Batch 800: Loss = 0.0496
# Batch 900: Loss = 0.0496
# Epoch 54: Loss = 0.4958
# Batch 0: Loss = 0.0496
# Batch 100: Loss = 0.0496
# Batch 200: Loss = 0.0496
# Batch 300: Loss = 0.0496
# Batch 400: Loss = 0.0496
# Batch 500: Loss = 0.0496
# Batch 600: Loss = 0.0496
# Batch 700: Loss = 0.0496
# Batch 800: Loss = 0.0496
# Batch 900: Loss = 0.0495
# Epoch 55: Loss = 0.4956
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0495
# Batch 200: Loss = 0.0495
# Batch 300: Loss = 0.0495
# Batch 400: Loss = 0.0495
# Batch 500: Loss = 0.0495
# Batch 600: Loss = 0.0495
# Batch 700: Loss = 0.0495
# Batch 800: Loss = 0.0495
# Batch 900: Loss = 0.0495
# Epoch 56: Loss = 0.4954
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0495
# Batch 200: Loss = 0.0495
# Batch 300: Loss = 0.0495
# Batch 400: Loss = 0.0495
# Batch 500: Loss = 0.0495
# Batch 600: Loss = 0.0495
# Batch 700: Loss = 0.0495
# Batch 800: Loss = 0.0495
# Batch 900: Loss = 0.0495
# Epoch 57: Loss = 0.4952
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0495
# Batch 200: Loss = 0.0495
# Batch 300: Loss = 0.0495
# Batch 400: Loss = 0.0495
# Batch 500: Loss = 0.0495
# Batch 600: Loss = 0.0495
# Batch 700: Loss = 0.0495
# Batch 800: Loss = 0.0495
# Batch 900: Loss = 0.0495
# Epoch 58: Loss = 0.4950
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0495
# Batch 200: Loss = 0.0495
# Batch 300: Loss = 0.0495
# Batch 400: Loss = 0.0495
# Batch 500: Loss = 0.0495
# Batch 600: Loss = 0.0495
# Batch 700: Loss = 0.0495
# Batch 800: Loss = 0.0495
# Batch 900: Loss = 0.0495
# Epoch 59: Loss = 0.4948
# Batch 0: Loss = 0.0495
# Batch 100: Loss = 0.0495
# Batch 200: Loss = 0.0495
# Batch 300: Loss = 0.0495
# Batch 400: Loss = 0.0495
# Batch 500: Loss = 0.0495
# Batch 600: Loss = 0.0495
# Batch 700: Loss = 0.0495
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 60: Loss = 0.4946
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 61: Loss = 0.4944
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 62: Loss = 0.4943
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 63: Loss = 0.4942
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 64: Loss = 0.4941
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 65: Loss = 0.4940
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 66: Loss = 0.4939
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 67: Loss = 0.4938
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 68: Loss = 0.4937
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0494
# Batch 400: Loss = 0.0494
# Batch 500: Loss = 0.0494
# Batch 600: Loss = 0.0494
# Batch 700: Loss = 0.0494
# Batch 800: Loss = 0.0494
# Batch 900: Loss = 0.0494
# Epoch 69: Loss = 0.4936
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0494
# Batch 200: Loss = 0.0494
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 70: Loss = 0.4935
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 71: Loss = 0.4934
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 72: Loss = 0.4934
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 73: Loss = 0.4933
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 74: Loss = 0.4933
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 75: Loss = 0.4932
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 76: Loss = 0.4932
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 77: Loss = 0.4931
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 78: Loss = 0.4931
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 79: Loss = 0.4930
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 80: Loss = 0.4930
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 81: Loss = 0.4929
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 82: Loss = 0.4929
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 83: Loss = 0.4929
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 84: Loss = 0.4928
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 85: Loss = 0.4928
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 86: Loss = 0.4928
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 87: Loss = 0.4928
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 88: Loss = 0.4927
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 89: Loss = 0.4927
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 90: Loss = 0.4927
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 91: Loss = 0.4927
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 92: Loss = 0.4927
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 93: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 94: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 95: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 96: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 97: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 98: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 99: Loss = 0.4926
# Batch 0: Loss = 0.0493
# Batch 100: Loss = 0.0493
# Batch 200: Loss = 0.0493
# Batch 300: Loss = 0.0493
# Batch 400: Loss = 0.0493
# Batch 500: Loss = 0.0493
# Batch 600: Loss = 0.0493
# Batch 700: Loss = 0.0493
# Batch 800: Loss = 0.0493
# Batch 900: Loss = 0.0493
# Epoch 100: Loss = 0.4926

# %% [markdown]
# Using a different optimizer - Adam

# %%
from torch.optim.lr_scheduler import StepLR
from torch.optim import Adam


num_iterations = 100
learning_rate = 0.5 # higher than before as we will reduce this over steps

w = torch.zeros(size=(nx,1), requires_grad=True)
b = torch.zeros(size=(1,1), requires_grad=True)

optimizer = Adam([w, b], lr=learning_rate)
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)

for step in range(num_iterations):

    # shuffle X, Y
    perm = torch.randperm(m)
    X_shuffled, Y_shuffled = X[:, perm], Y[:, perm]

    epoch_loss = 0.0

    # use mini-batches
    for batch in range(0, m, 100):

        X_batch, Y_batch = X_shuffled[:, batch:batch+100], Y_shuffled[:, batch:batch+100]

        z = w.T @ X_shuffled + b
        a = sigmoid(z)

        loss = binary_cross_entropy_loss(a, Y_shuffled)
        epoch_loss += loss

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        print(f"Batch {batch}: Loss = {loss.item():.4f}")

    scheduler.step()

    print(f"Epoch {step+1}: Loss = {epoch_loss.item():.4f}")
# Out:
# Batch 0: Loss = 0.6931
# Batch 100: Loss = 0.4980
# Batch 200: Loss = 0.3441
# Batch 300: Loss = 0.2710
# Batch 400: Loss = 0.2304
# Batch 500: Loss = 0.1988
# Batch 600: Loss = 0.1727
# Batch 700: Loss = 0.1523
# Batch 800: Loss = 0.1375
# Batch 900: Loss = 0.1272
# Epoch 1: Loss = 2.8251
# Batch 0: Loss = 0.1200
# Batch 100: Loss = 0.1145
# Batch 200: Loss = 0.1096
# Batch 300: Loss = 0.1050
# Batch 400: Loss = 0.1004
# Batch 500: Loss = 0.0961
# Batch 600: Loss = 0.0921
# Batch 700: Loss = 0.0888
# Batch 800: Loss = 0.0861
# Batch 900: Loss = 0.0840
# Epoch 2: Loss = 0.9965
# Batch 0: Loss = 0.0823
# Batch 100: Loss = 0.0808
# Batch 200: Loss = 0.0794
# Batch 300: Loss = 0.0780
# Batch 400: Loss = 0.0766
# Batch 500: Loss = 0.0752
# Batch 600: Loss = 0.0738
# Batch 700: Loss = 0.0725
# Batch 800: Loss = 0.0714
# Batch 900: Loss = 0.0705
# Epoch 3: Loss = 0.7605
# Batch 0: Loss = 0.0697
# Batch 100: Loss = 0.0690
# Batch 200: Loss = 0.0683
# Batch 300: Loss = 0.0677
# Batch 400: Loss = 0.0670
# Batch 500: Loss = 0.0663
# Batch 600: Loss = 0.0657
# Batch 700: Loss = 0.0650
# Batch 800: Loss = 0.0644
# Batch 900: Loss = 0.0639
# Epoch 4: Loss = 0.6669
# Batch 0: Loss = 0.0634
# Batch 100: Loss = 0.0629
# Batch 200: Loss = 0.0625
# Batch 300: Loss = 0.0621
# Batch 400: Loss = 0.0617
# Batch 500: Loss = 0.0613
# Batch 600: Loss = 0.0609
# Batch 700: Loss = 0.0604
# Batch 800: Loss = 0.0601
# Batch 900: Loss = 0.0597
# Epoch 5: Loss = 0.6148
# Batch 0: Loss = 0.0593
# Batch 100: Loss = 0.0590
# Batch 200: Loss = 0.0587
# Batch 300: Loss = 0.0583
# Batch 400: Loss = 0.0580
# Batch 500: Loss = 0.0577
# Batch 600: Loss = 0.0574
# Batch 700: Loss = 0.0571
# Batch 800: Loss = 0.0568
# Batch 900: Loss = 0.0565
# Epoch 6: Loss = 0.5789
# Batch 0: Loss = 0.0562
# Batch 100: Loss = 0.0560
# Batch 200: Loss = 0.0557
# Batch 300: Loss = 0.0554
# Batch 400: Loss = 0.0552
# Batch 500: Loss = 0.0549
# Batch 600: Loss = 0.0547
# Batch 700: Loss = 0.0544
# Batch 800: Loss = 0.0542
# Batch 900: Loss = 0.0539
# Epoch 7: Loss = 0.5505
# Batch 0: Loss = 0.0537
# Batch 100: Loss = 0.0534
# Batch 200: Loss = 0.0532
# Batch 300: Loss = 0.0530
# Batch 400: Loss = 0.0527
# Batch 500: Loss = 0.0525
# Batch 600: Loss = 0.0523
# Batch 700: Loss = 0.0521
# Batch 800: Loss = 0.0519
# Batch 900: Loss = 0.0516
# Epoch 8: Loss = 0.5264
# Batch 0: Loss = 0.0514
# Batch 100: Loss = 0.0512
# Batch 200: Loss = 0.0510
# Batch 300: Loss = 0.0508
# Batch 400: Loss = 0.0506
# Batch 500: Loss = 0.0504
# Batch 600: Loss = 0.0502
# Batch 700: Loss = 0.0500
# Batch 800: Loss = 0.0498
# Batch 900: Loss = 0.0496
# Epoch 9: Loss = 0.5051
# Batch 0: Loss = 0.0494
# Batch 100: Loss = 0.0492
# Batch 200: Loss = 0.0491
# Batch 300: Loss = 0.0489
# Batch 400: Loss = 0.0487
# Batch 500: Loss = 0.0485
# Batch 600: Loss = 0.0483
# Batch 700: Loss = 0.0481
# Batch 800: Loss = 0.0480
# Batch 900: Loss = 0.0478
# Epoch 10: Loss = 0.4860
# Batch 0: Loss = 0.0476
# Batch 100: Loss = 0.0475
# Batch 200: Loss = 0.0475
# Batch 300: Loss = 0.0474
# Batch 400: Loss = 0.0473
# Batch 500: Loss = 0.0472
# Batch 600: Loss = 0.0471
# Batch 700: Loss = 0.0470
# Batch 800: Loss = 0.0469
# Batch 900: Loss = 0.0469
# Epoch 11: Loss = 0.4724
# Batch 0: Loss = 0.0468
# Batch 100: Loss = 0.0467
# Batch 200: Loss = 0.0466
# Batch 300: Loss = 0.0465
# Batch 400: Loss = 0.0465
# Batch 500: Loss = 0.0464
# Batch 600: Loss = 0.0463
# Batch 700: Loss = 0.0462
# Batch 800: Loss = 0.0461
# Batch 900: Loss = 0.0461
# Epoch 12: Loss = 0.4642
# Batch 0: Loss = 0.0460
# Batch 100: Loss = 0.0459
# Batch 200: Loss = 0.0458
# Batch 300: Loss = 0.0457
# Batch 400: Loss = 0.0457
# Batch 500: Loss = 0.0456
# Batch 600: Loss = 0.0455
# Batch 700: Loss = 0.0454
# Batch 800: Loss = 0.0453
# Batch 900: Loss = 0.0453
# Epoch 13: Loss = 0.4562
# Batch 0: Loss = 0.0452
# Batch 100: Loss = 0.0451
# Batch 200: Loss = 0.0450
# Batch 300: Loss = 0.0450
# Batch 400: Loss = 0.0449
# Batch 500: Loss = 0.0448
# Batch 600: Loss = 0.0447
# Batch 700: Loss = 0.0447
# Batch 800: Loss = 0.0446
# Batch 900: Loss = 0.0445
# Epoch 14: Loss = 0.4485
# Batch 0: Loss = 0.0444
# Batch 100: Loss = 0.0444
# Batch 200: Loss = 0.0443
# Batch 300: Loss = 0.0442
# Batch 400: Loss = 0.0441
# Batch 500: Loss = 0.0441
# Batch 600: Loss = 0.0440
# Batch 700: Loss = 0.0439
# Batch 800: Loss = 0.0438
# Batch 900: Loss = 0.0438
# Epoch 15: Loss = 0.4410
# Batch 0: Loss = 0.0437
# Batch 100: Loss = 0.0436
# Batch 200: Loss = 0.0435
# Batch 300: Loss = 0.0435
# Batch 400: Loss = 0.0434
# Batch 500: Loss = 0.0433
# Batch 600: Loss = 0.0433
# Batch 700: Loss = 0.0432
# Batch 800: Loss = 0.0431
# Batch 900: Loss = 0.0430
# Epoch 16: Loss = 0.4337
# Batch 0: Loss = 0.0430
# Batch 100: Loss = 0.0429
# Batch 200: Loss = 0.0428
# Batch 300: Loss = 0.0428
# Batch 400: Loss = 0.0427
# Batch 500: Loss = 0.0426
# Batch 600: Loss = 0.0426
# Batch 700: Loss = 0.0425
# Batch 800: Loss = 0.0424
# Batch 900: Loss = 0.0424
# Epoch 17: Loss = 0.4266
# Batch 0: Loss = 0.0423
# Batch 100: Loss = 0.0422
# Batch 200: Loss = 0.0421
# Batch 300: Loss = 0.0421
# Batch 400: Loss = 0.0420
# Batch 500: Loss = 0.0419
# Batch 600: Loss = 0.0419
# Batch 700: Loss = 0.0418
# Batch 800: Loss = 0.0417
# Batch 900: Loss = 0.0417
# Epoch 18: Loss = 0.4198
# Batch 0: Loss = 0.0416
# Batch 100: Loss = 0.0415
# Batch 200: Loss = 0.0415
# Batch 300: Loss = 0.0414
# Batch 400: Loss = 0.0413
# Batch 500: Loss = 0.0413
# Batch 600: Loss = 0.0412
# Batch 700: Loss = 0.0412
# Batch 800: Loss = 0.0411
# Batch 900: Loss = 0.0410
# Epoch 19: Loss = 0.4131
# Batch 0: Loss = 0.0410
# Batch 100: Loss = 0.0409
# Batch 200: Loss = 0.0408
# Batch 300: Loss = 0.0408
# Batch 400: Loss = 0.0407
# Batch 500: Loss = 0.0406
# Batch 600: Loss = 0.0406
# Batch 700: Loss = 0.0405
# Batch 800: Loss = 0.0405
# Batch 900: Loss = 0.0404
# Epoch 20: Loss = 0.4067
# Batch 0: Loss = 0.0403
# Batch 100: Loss = 0.0403
# Batch 200: Loss = 0.0403
# Batch 300: Loss = 0.0402
# Batch 400: Loss = 0.0402
# Batch 500: Loss = 0.0402
# Batch 600: Loss = 0.0401
# Batch 700: Loss = 0.0401
# Batch 800: Loss = 0.0401
# Batch 900: Loss = 0.0401
# Epoch 21: Loss = 0.4019
# Batch 0: Loss = 0.0400
# Batch 100: Loss = 0.0400
# Batch 200: Loss = 0.0400
# Batch 300: Loss = 0.0399
# Batch 400: Loss = 0.0399
# Batch 500: Loss = 0.0399
# Batch 600: Loss = 0.0398
# Batch 700: Loss = 0.0398
# Batch 800: Loss = 0.0398
# Batch 900: Loss = 0.0397
# Epoch 22: Loss = 0.3988
# Batch 0: Loss = 0.0397
# Batch 100: Loss = 0.0397
# Batch 200: Loss = 0.0397
# Batch 300: Loss = 0.0396
# Batch 400: Loss = 0.0396
# Batch 500: Loss = 0.0396
# Batch 600: Loss = 0.0395
# Batch 700: Loss = 0.0395
# Batch 800: Loss = 0.0395
# Batch 900: Loss = 0.0394
# Epoch 23: Loss = 0.3958
# Batch 0: Loss = 0.0394
# Batch 100: Loss = 0.0394
# Batch 200: Loss = 0.0394
# Batch 300: Loss = 0.0393
# Batch 400: Loss = 0.0393
# Batch 500: Loss = 0.0393
# Batch 600: Loss = 0.0392
# Batch 700: Loss = 0.0392
# Batch 800: Loss = 0.0392
# Batch 900: Loss = 0.0391
# Epoch 24: Loss = 0.3928
# Batch 0: Loss = 0.0391
# Batch 100: Loss = 0.0391
# Batch 200: Loss = 0.0391
# Batch 300: Loss = 0.0390
# Batch 400: Loss = 0.0390
# Batch 500: Loss = 0.0390
# Batch 600: Loss = 0.0389
# Batch 700: Loss = 0.0389
# Batch 800: Loss = 0.0389
# Batch 900: Loss = 0.0388
# Epoch 25: Loss = 0.3898
# Batch 0: Loss = 0.0388
# Batch 100: Loss = 0.0388
# Batch 200: Loss = 0.0388
# Batch 300: Loss = 0.0387
# Batch 400: Loss = 0.0387
# Batch 500: Loss = 0.0387
# Batch 600: Loss = 0.0386
# Batch 700: Loss = 0.0386
# Batch 800: Loss = 0.0386
# Batch 900: Loss = 0.0385
# Epoch 26: Loss = 0.3868
# Batch 0: Loss = 0.0385
# Batch 100: Loss = 0.0385
# Batch 200: Loss = 0.0385
# Batch 300: Loss = 0.0384
# Batch 400: Loss = 0.0384
# Batch 500: Loss = 0.0384
# Batch 600: Loss = 0.0383
# Batch 700: Loss = 0.0383
# Batch 800: Loss = 0.0383
# Batch 900: Loss = 0.0383
# Epoch 27: Loss = 0.3839
# Batch 0: Loss = 0.0382
# Batch 100: Loss = 0.0382
# Batch 200: Loss = 0.0382
# Batch 300: Loss = 0.0381
# Batch 400: Loss = 0.0381
# Batch 500: Loss = 0.0381
# Batch 600: Loss = 0.0381
# Batch 700: Loss = 0.0380
# Batch 800: Loss = 0.0380
# Batch 900: Loss = 0.0380
# Epoch 28: Loss = 0.3809
# Batch 0: Loss = 0.0379
# Batch 100: Loss = 0.0379
# Batch 200: Loss = 0.0379
# Batch 300: Loss = 0.0378
# Batch 400: Loss = 0.0378
# Batch 500: Loss = 0.0378
# Batch 600: Loss = 0.0378
# Batch 700: Loss = 0.0377
# Batch 800: Loss = 0.0377
# Batch 900: Loss = 0.0377
# Epoch 29: Loss = 0.3781
# Batch 0: Loss = 0.0376
# Batch 100: Loss = 0.0376
# Batch 200: Loss = 0.0376
# Batch 300: Loss = 0.0376
# Batch 400: Loss = 0.0375
# Batch 500: Loss = 0.0375
# Batch 600: Loss = 0.0375
# Batch 700: Loss = 0.0374
# Batch 800: Loss = 0.0374
# Batch 900: Loss = 0.0374
# Epoch 30: Loss = 0.3752
# Batch 0: Loss = 0.0374
# Batch 100: Loss = 0.0373
# Batch 200: Loss = 0.0373
# Batch 300: Loss = 0.0373
# Batch 400: Loss = 0.0373
# Batch 500: Loss = 0.0373
# Batch 600: Loss = 0.0373
# Batch 700: Loss = 0.0373
# Batch 800: Loss = 0.0372
# Batch 900: Loss = 0.0372
# Epoch 31: Loss = 0.3730
# Batch 0: Loss = 0.0372
# Batch 100: Loss = 0.0372
# Batch 200: Loss = 0.0372
# Batch 300: Loss = 0.0372
# Batch 400: Loss = 0.0372
# Batch 500: Loss = 0.0371
# Batch 600: Loss = 0.0371
# Batch 700: Loss = 0.0371
# Batch 800: Loss = 0.0371
# Batch 900: Loss = 0.0371
# Epoch 32: Loss = 0.3716
# Batch 0: Loss = 0.0371
# Batch 100: Loss = 0.0371
# Batch 200: Loss = 0.0370
# Batch 300: Loss = 0.0370
# Batch 400: Loss = 0.0370
# Batch 500: Loss = 0.0370
# Batch 600: Loss = 0.0370
# Batch 700: Loss = 0.0370
# Batch 800: Loss = 0.0370
# Batch 900: Loss = 0.0370
# Epoch 33: Loss = 0.3701
# Batch 0: Loss = 0.0369
# Batch 100: Loss = 0.0369
# Batch 200: Loss = 0.0369
# Batch 300: Loss = 0.0369
# Batch 400: Loss = 0.0369
# Batch 500: Loss = 0.0369
# Batch 600: Loss = 0.0369
# Batch 700: Loss = 0.0368
# Batch 800: Loss = 0.0368
# Batch 900: Loss = 0.0368
# Epoch 34: Loss = 0.3687
# Batch 0: Loss = 0.0368
# Batch 100: Loss = 0.0368
# Batch 200: Loss = 0.0368
# Batch 300: Loss = 0.0368
# Batch 400: Loss = 0.0367
# Batch 500: Loss = 0.0367
# Batch 600: Loss = 0.0367
# Batch 700: Loss = 0.0367
# Batch 800: Loss = 0.0367
# Batch 900: Loss = 0.0367
# Epoch 35: Loss = 0.3673
# Batch 0: Loss = 0.0367
# Batch 100: Loss = 0.0366
# Batch 200: Loss = 0.0366
# Batch 300: Loss = 0.0366
# Batch 400: Loss = 0.0366
# Batch 500: Loss = 0.0366
# Batch 600: Loss = 0.0366
# Batch 700: Loss = 0.0366
# Batch 800: Loss = 0.0365
# Batch 900: Loss = 0.0365
# Epoch 36: Loss = 0.3659
# Batch 0: Loss = 0.0365
# Batch 100: Loss = 0.0365
# Batch 200: Loss = 0.0365
# Batch 300: Loss = 0.0365
# Batch 400: Loss = 0.0365
# Batch 500: Loss = 0.0364
# Batch 600: Loss = 0.0364
# Batch 700: Loss = 0.0364
# Batch 800: Loss = 0.0364
# Batch 900: Loss = 0.0364
# Epoch 37: Loss = 0.3644
# Batch 0: Loss = 0.0364
# Batch 100: Loss = 0.0364
# Batch 200: Loss = 0.0363
# Batch 300: Loss = 0.0363
# Batch 400: Loss = 0.0363
# Batch 500: Loss = 0.0363
# Batch 600: Loss = 0.0363
# Batch 700: Loss = 0.0363
# Batch 800: Loss = 0.0363
# Batch 900: Loss = 0.0362
# Epoch 38: Loss = 0.3630
# Batch 0: Loss = 0.0362
# Batch 100: Loss = 0.0362
# Batch 200: Loss = 0.0362
# Batch 300: Loss = 0.0362
# Batch 400: Loss = 0.0362
# Batch 500: Loss = 0.0362
# Batch 600: Loss = 0.0361
# Batch 700: Loss = 0.0361
# Batch 800: Loss = 0.0361
# Batch 900: Loss = 0.0361
# Epoch 39: Loss = 0.3616
# Batch 0: Loss = 0.0361
# Batch 100: Loss = 0.0361
# Batch 200: Loss = 0.0361
# Batch 300: Loss = 0.0360
# Batch 400: Loss = 0.0360
# Batch 500: Loss = 0.0360
# Batch 600: Loss = 0.0360
# Batch 700: Loss = 0.0360
# Batch 800: Loss = 0.0360
# Batch 900: Loss = 0.0360
# Epoch 40: Loss = 0.3601
# Batch 0: Loss = 0.0359
# Batch 100: Loss = 0.0359
# Batch 200: Loss = 0.0359
# Batch 300: Loss = 0.0359
# Batch 400: Loss = 0.0359
# Batch 500: Loss = 0.0359
# Batch 600: Loss = 0.0359
# Batch 700: Loss = 0.0359
# Batch 800: Loss = 0.0359
# Batch 900: Loss = 0.0359
# Epoch 41: Loss = 0.3590
# Batch 0: Loss = 0.0359
# Batch 100: Loss = 0.0359
# Batch 200: Loss = 0.0358
# Batch 300: Loss = 0.0358
# Batch 400: Loss = 0.0358
# Batch 500: Loss = 0.0358
# Batch 600: Loss = 0.0358
# Batch 700: Loss = 0.0358
# Batch 800: Loss = 0.0358
# Batch 900: Loss = 0.0358
# Epoch 42: Loss = 0.3583
# Batch 0: Loss = 0.0358
# Batch 100: Loss = 0.0358
# Batch 200: Loss = 0.0358
# Batch 300: Loss = 0.0358
# Batch 400: Loss = 0.0358
# Batch 500: Loss = 0.0358
# Batch 600: Loss = 0.0357
# Batch 700: Loss = 0.0357
# Batch 800: Loss = 0.0357
# Batch 900: Loss = 0.0357
# Epoch 43: Loss = 0.3576
# Batch 0: Loss = 0.0357
# Batch 100: Loss = 0.0357
# Batch 200: Loss = 0.0357
# Batch 300: Loss = 0.0357
# Batch 400: Loss = 0.0357
# Batch 500: Loss = 0.0357
# Batch 600: Loss = 0.0357
# Batch 700: Loss = 0.0357
# Batch 800: Loss = 0.0357
# Batch 900: Loss = 0.0357
# Epoch 44: Loss = 0.3569
# Batch 0: Loss = 0.0356
# Batch 100: Loss = 0.0356
# Batch 200: Loss = 0.0356
# Batch 300: Loss = 0.0356
# Batch 400: Loss = 0.0356
# Batch 500: Loss = 0.0356
# Batch 600: Loss = 0.0356
# Batch 700: Loss = 0.0356
# Batch 800: Loss = 0.0356
# Batch 900: Loss = 0.0356
# Epoch 45: Loss = 0.3561
# Batch 0: Loss = 0.0356
# Batch 100: Loss = 0.0356
# Batch 200: Loss = 0.0356
# Batch 300: Loss = 0.0356
# Batch 400: Loss = 0.0355
# Batch 500: Loss = 0.0355
# Batch 600: Loss = 0.0355
# Batch 700: Loss = 0.0355
# Batch 800: Loss = 0.0355
# Batch 900: Loss = 0.0355
# Epoch 46: Loss = 0.3554
# Batch 0: Loss = 0.0355
# Batch 100: Loss = 0.0355
# Batch 200: Loss = 0.0355
# Batch 300: Loss = 0.0355
# Batch 400: Loss = 0.0355
# Batch 500: Loss = 0.0355
# Batch 600: Loss = 0.0355
# Batch 700: Loss = 0.0354
# Batch 800: Loss = 0.0354
# Batch 900: Loss = 0.0354
# Epoch 47: Loss = 0.3547
# Batch 0: Loss = 0.0354
# Batch 100: Loss = 0.0354
# Batch 200: Loss = 0.0354
# Batch 300: Loss = 0.0354
# Batch 400: Loss = 0.0354
# Batch 500: Loss = 0.0354
# Batch 600: Loss = 0.0354
# Batch 700: Loss = 0.0354
# Batch 800: Loss = 0.0354
# Batch 900: Loss = 0.0354
# Epoch 48: Loss = 0.3539
# Batch 0: Loss = 0.0354
# Batch 100: Loss = 0.0353
# Batch 200: Loss = 0.0353
# Batch 300: Loss = 0.0353
# Batch 400: Loss = 0.0353
# Batch 500: Loss = 0.0353
# Batch 600: Loss = 0.0353
# Batch 700: Loss = 0.0353
# Batch 800: Loss = 0.0353
# Batch 900: Loss = 0.0353
# Epoch 49: Loss = 0.3532
# Batch 0: Loss = 0.0353
# Batch 100: Loss = 0.0353
# Batch 200: Loss = 0.0353
# Batch 300: Loss = 0.0353
# Batch 400: Loss = 0.0352
# Batch 500: Loss = 0.0352
# Batch 600: Loss = 0.0352
# Batch 700: Loss = 0.0352
# Batch 800: Loss = 0.0352
# Batch 900: Loss = 0.0352
# Epoch 50: Loss = 0.3524
# Batch 0: Loss = 0.0352
# Batch 100: Loss = 0.0352
# Batch 200: Loss = 0.0352
# Batch 300: Loss = 0.0352
# Batch 400: Loss = 0.0352
# Batch 500: Loss = 0.0352
# Batch 600: Loss = 0.0352
# Batch 700: Loss = 0.0352
# Batch 800: Loss = 0.0352
# Batch 900: Loss = 0.0352
# Epoch 51: Loss = 0.3518
# Batch 0: Loss = 0.0352
# Batch 100: Loss = 0.0352
# Batch 200: Loss = 0.0352
# Batch 300: Loss = 0.0352
# Batch 400: Loss = 0.0351
# Batch 500: Loss = 0.0351
# Batch 600: Loss = 0.0351
# Batch 700: Loss = 0.0351
# Batch 800: Loss = 0.0351
# Batch 900: Loss = 0.0351
# Epoch 52: Loss = 0.3515
# Batch 0: Loss = 0.0351
# Batch 100: Loss = 0.0351
# Batch 200: Loss = 0.0351
# Batch 300: Loss = 0.0351
# Batch 400: Loss = 0.0351
# Batch 500: Loss = 0.0351
# Batch 600: Loss = 0.0351
# Batch 700: Loss = 0.0351
# Batch 800: Loss = 0.0351
# Batch 900: Loss = 0.0351
# Epoch 53: Loss = 0.3511
# Batch 0: Loss = 0.0351
# Batch 100: Loss = 0.0351
# Batch 200: Loss = 0.0351
# Batch 300: Loss = 0.0351
# Batch 400: Loss = 0.0351
# Batch 500: Loss = 0.0351
# Batch 600: Loss = 0.0351
# Batch 700: Loss = 0.0351
# Batch 800: Loss = 0.0351
# Batch 900: Loss = 0.0351
# Epoch 54: Loss = 0.3507
# Batch 0: Loss = 0.0350
# Batch 100: Loss = 0.0350
# Batch 200: Loss = 0.0350
# Batch 300: Loss = 0.0350
# Batch 400: Loss = 0.0350
# Batch 500: Loss = 0.0350
# Batch 600: Loss = 0.0350
# Batch 700: Loss = 0.0350
# Batch 800: Loss = 0.0350
# Batch 900: Loss = 0.0350
# Epoch 55: Loss = 0.3503
# Batch 0: Loss = 0.0350
# Batch 100: Loss = 0.0350
# Batch 200: Loss = 0.0350
# Batch 300: Loss = 0.0350
# Batch 400: Loss = 0.0350
# Batch 500: Loss = 0.0350
# Batch 600: Loss = 0.0350
# Batch 700: Loss = 0.0350
# Batch 800: Loss = 0.0350
# Batch 900: Loss = 0.0350
# Epoch 56: Loss = 0.3499
# Batch 0: Loss = 0.0350
# Batch 100: Loss = 0.0350
# Batch 200: Loss = 0.0350
# Batch 300: Loss = 0.0350
# Batch 400: Loss = 0.0350
# Batch 500: Loss = 0.0349
# Batch 600: Loss = 0.0349
# Batch 700: Loss = 0.0349
# Batch 800: Loss = 0.0349
# Batch 900: Loss = 0.0349
# Epoch 57: Loss = 0.3495
# Batch 0: Loss = 0.0349
# Batch 100: Loss = 0.0349
# Batch 200: Loss = 0.0349
# Batch 300: Loss = 0.0349
# Batch 400: Loss = 0.0349
# Batch 500: Loss = 0.0349
# Batch 600: Loss = 0.0349
# Batch 700: Loss = 0.0349
# Batch 800: Loss = 0.0349
# Batch 900: Loss = 0.0349
# Epoch 58: Loss = 0.3491
# Batch 0: Loss = 0.0349
# Batch 100: Loss = 0.0349
# Batch 200: Loss = 0.0349
# Batch 300: Loss = 0.0349
# Batch 400: Loss = 0.0349
# Batch 500: Loss = 0.0349
# Batch 600: Loss = 0.0349
# Batch 700: Loss = 0.0349
# Batch 800: Loss = 0.0349
# Batch 900: Loss = 0.0349
# Epoch 59: Loss = 0.3487
# Batch 0: Loss = 0.0348
# Batch 100: Loss = 0.0348
# Batch 200: Loss = 0.0348
# Batch 300: Loss = 0.0348
# Batch 400: Loss = 0.0348
# Batch 500: Loss = 0.0348
# Batch 600: Loss = 0.0348
# Batch 700: Loss = 0.0348
# Batch 800: Loss = 0.0348
# Batch 900: Loss = 0.0348
# Epoch 60: Loss = 0.3483
# Batch 0: Loss = 0.0348
# Batch 100: Loss = 0.0348
# Batch 200: Loss = 0.0348
# Batch 300: Loss = 0.0348
# Batch 400: Loss = 0.0348
# Batch 500: Loss = 0.0348
# Batch 600: Loss = 0.0348
# Batch 700: Loss = 0.0348
# Batch 800: Loss = 0.0348
# Batch 900: Loss = 0.0348
# Epoch 61: Loss = 0.3480
# Batch 0: Loss = 0.0348
# Batch 100: Loss = 0.0348
# Batch 200: Loss = 0.0348
# Batch 300: Loss = 0.0348
# Batch 400: Loss = 0.0348
# Batch 500: Loss = 0.0348
# Batch 600: Loss = 0.0348
# Batch 700: Loss = 0.0348
# Batch 800: Loss = 0.0348
# Batch 900: Loss = 0.0348
# Epoch 62: Loss = 0.3478
# Batch 0: Loss = 0.0348
# Batch 100: Loss = 0.0348
# Batch 200: Loss = 0.0348
# Batch 300: Loss = 0.0348
# Batch 400: Loss = 0.0348
# Batch 500: Loss = 0.0348
# Batch 600: Loss = 0.0348
# Batch 700: Loss = 0.0348
# Batch 800: Loss = 0.0348
# Batch 900: Loss = 0.0348
# Epoch 63: Loss = 0.3476
# Batch 0: Loss = 0.0347
# Batch 100: Loss = 0.0347
# Batch 200: Loss = 0.0347
# Batch 300: Loss = 0.0347
# Batch 400: Loss = 0.0347
# Batch 500: Loss = 0.0347
# Batch 600: Loss = 0.0347
# Batch 700: Loss = 0.0347
# Batch 800: Loss = 0.0347
# Batch 900: Loss = 0.0347
# Epoch 64: Loss = 0.3474
# Batch 0: Loss = 0.0347
# Batch 100: Loss = 0.0347
# Batch 200: Loss = 0.0347
# Batch 300: Loss = 0.0347
# Batch 400: Loss = 0.0347
# Batch 500: Loss = 0.0347
# Batch 600: Loss = 0.0347
# Batch 700: Loss = 0.0347
# Batch 800: Loss = 0.0347
# Batch 900: Loss = 0.0347
# Epoch 65: Loss = 0.3472
# Batch 0: Loss = 0.0347
# Batch 100: Loss = 0.0347
# Batch 200: Loss = 0.0347
# Batch 300: Loss = 0.0347
# Batch 400: Loss = 0.0347
# Batch 500: Loss = 0.0347
# Batch 600: Loss = 0.0347
# Batch 700: Loss = 0.0347
# Batch 800: Loss = 0.0347
# Batch 900: Loss = 0.0347
# Epoch 66: Loss = 0.3470
# Batch 0: Loss = 0.0347
# Batch 100: Loss = 0.0347
# Batch 200: Loss = 0.0347
# Batch 300: Loss = 0.0347
# Batch 400: Loss = 0.0347
# Batch 500: Loss = 0.0347
# Batch 600: Loss = 0.0347
# Batch 700: Loss = 0.0347
# Batch 800: Loss = 0.0347
# Batch 900: Loss = 0.0347
# Epoch 67: Loss = 0.3468
# Batch 0: Loss = 0.0347
# Batch 100: Loss = 0.0347
# Batch 200: Loss = 0.0347
# Batch 300: Loss = 0.0347
# Batch 400: Loss = 0.0347
# Batch 500: Loss = 0.0347
# Batch 600: Loss = 0.0347
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 68: Loss = 0.3465
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 69: Loss = 0.3463
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 70: Loss = 0.3461
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 71: Loss = 0.3459
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 72: Loss = 0.3458
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 73: Loss = 0.3457
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0346
# Batch 500: Loss = 0.0346
# Batch 600: Loss = 0.0346
# Batch 700: Loss = 0.0346
# Batch 800: Loss = 0.0346
# Batch 900: Loss = 0.0346
# Epoch 74: Loss = 0.3456
# Batch 0: Loss = 0.0346
# Batch 100: Loss = 0.0346
# Batch 200: Loss = 0.0346
# Batch 300: Loss = 0.0346
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 75: Loss = 0.3455
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 76: Loss = 0.3454
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 77: Loss = 0.3453
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 78: Loss = 0.3451
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 79: Loss = 0.3450
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 80: Loss = 0.3449
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 81: Loss = 0.3448
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 82: Loss = 0.3448
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 83: Loss = 0.3447
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 84: Loss = 0.3446
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0345
# Batch 800: Loss = 0.0345
# Batch 900: Loss = 0.0345
# Epoch 85: Loss = 0.3446
# Batch 0: Loss = 0.0345
# Batch 100: Loss = 0.0345
# Batch 200: Loss = 0.0345
# Batch 300: Loss = 0.0345
# Batch 400: Loss = 0.0345
# Batch 500: Loss = 0.0345
# Batch 600: Loss = 0.0345
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 86: Loss = 0.3445
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 87: Loss = 0.3445
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 88: Loss = 0.3444
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 89: Loss = 0.3443
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 90: Loss = 0.3443
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 91: Loss = 0.3442
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 92: Loss = 0.3442
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 93: Loss = 0.3441
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 94: Loss = 0.3441
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 95: Loss = 0.3441
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 96: Loss = 0.3440
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 97: Loss = 0.3440
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 98: Loss = 0.3440
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 99: Loss = 0.3439
# Batch 0: Loss = 0.0344
# Batch 100: Loss = 0.0344
# Batch 200: Loss = 0.0344
# Batch 300: Loss = 0.0344
# Batch 400: Loss = 0.0344
# Batch 500: Loss = 0.0344
# Batch 600: Loss = 0.0344
# Batch 700: Loss = 0.0344
# Batch 800: Loss = 0.0344
# Batch 900: Loss = 0.0344
# Epoch 100: Loss = 0.3439
